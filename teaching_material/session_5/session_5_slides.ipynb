# %% [markdown]
# # Session 5: Case 1
#
# *Nicklas Johansen & Jacob Troelsgård*

# %% [markdown]
# ## Agenda
#
# In this session, we will prepare for solving our first case:
# - Reading files
# - Functions
# - Practical Organiztional Theory
# - How to solve a case

# %% [markdown]
# ## Recap
#
# - Missings and Duplicated Data
# - Combining Data Sets
# - Split-Apply-Combine
# - Rehaping Data

# %%
# Loading packages

import numpy as np
import pandas as pd
import seaborn as sns

tips = sns.load_dataset('tips')
titanic = sns.load_dataset('titanic')

# %% [markdown]
# ### Reading Files

# %% [markdown]
# Sometimes reading a .csv file...

# %%
pd.read_csv('data.csv')
# Out:
#   Name;Tænder;Indkomst
# 0        Nicklas;4;400
# 1          Jacob;6;500
# 2         Preben;8;800
# 3          Randi;1;200

# %% [markdown]
# ... requires us to state the seperator

# %%
pd.read_csv('data.csv', sep = ';')
# Out:
#       Name  Tænder  Indkomst
# 0  Nicklas       4       400
# 1    Jacob       6       500
# 2   Preben       8       800
# 3    Randi       1       200

# %% [markdown]
# You can also read a .xlsx file...

# %%
pd.read_excel('data.xlsx')
# Out:
#       Name  Tænder  Indkomst
# 0  Nicklas       4       400
# 1    Jacob       6       500
# 2   Preben       8       800
# 3    Randi       1       200

# %% [markdown]
# ... sometimes you may...

# %%
pd.read_excel('data_2.xlsx')
# Out:
#    1
# 0  2
# 1  3

# %% [markdown]
# ... need to specify which sheet you want to import.

# %%
pd.read_excel('data_2.xlsx', sheet_name='Sheet2')
# Out:
#       Name  Tænder  Indkomst
# 0  Nicklas       4       400
# 1    Jacob       6       500
# 2   Preben       8       800
# 3    Randi       1       200

# %% [markdown]
# Please notice that this only works because the files we read is located in the same working directory as out jupyter notebook.
#
# If you want to work with mutiple directories you might want to learn about the python module [`os`](https://www.geeksforgeeks.org/os-module-python-examples/).
# ```python
#     import os
#     # Python program to explain os.getcwd() method
#
#     # importing os module
#     import os
#
#     # Get the current working
#     # directory (CWD)
#     cwd = os.getcwd()
#
#     # Print the current working
#     # directory (CWD)
#     print("Current working directory:", cwd)
# ```

# %% [markdown]
# ## Functions
#
# Sometimes we need to create functions that can handle specific data wrangling challenges. Later they can easily be applied to our datafram using `apply`. Let look at two examples.

# %%
# from seaborn

titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone aldersgruppe
# 0    man        True  NaN  Southampton    no  False      Tyverne
# 1  woman       False    C    Cherbourg   yes  False   Trediverne
# 2  woman       False  NaN  Southampton   yes   True      Tyverne
# 3  woman       False    C  Southampton   yes  False   Trediverne
# 4    man        True  NaN  Southampton    no   True   Trediverne

# %%
# Function that splits people into age gorups

def lav_aldersgruppe(var):
    if var < 20:
        return 'Teenager'
    if var < 30:
        return 'Tyverne'
    if var < 40:
        return 'Trediverne'
    else:
        'Gammel'
        
titanic['aldersgruppe'] = titanic['age'].apply(lav_aldersgruppe)
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone aldersgruppe
# 0      man        True  NaN  Southampton    no  False      Tyverne
# 1    woman       False    C    Cherbourg   yes  False   Trediverne
# 2    woman       False  NaN  Southampton   yes   True      Tyverne
# 3    woman       False    C  Southampton   yes  False   Trediverne
# 4      man        True  NaN  Southampton    no   True   Trediverne
# ..     ...         ...  ...          ...   ...    ...          ...
# 886    man        True  NaN  Southampton    no   True      Tyverne
# 887  woman       False    B  Southampton   yes   True     Teenager
# 888  woman       False  NaN  Southampton    no  False         None
# 889    man        True    C    Cherbourg   yes   True      Tyverne
# 890    man        True  NaN   Queenstown    no   True   Trediverne
#
# [891 rows x 16 columns]

# %%
# Alternative strucutre:
# Stored the answer in a result and return it in the end

def lav_aldersgruppe(var):
    if var >10 & var < 20:
        result = 'Teenager'
    if var >20 & var < 30:
        result = 'Tyverne'
    return result

# %%
# from ex. 4.1.1
# we want to slit each person into a income group based on their occupation
url = f'https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data'
labels = ['age','workclass', 'fnlwgt', 'educ', 'educ_num', 'marital_status', 'occupation','relationship', 'race', 'sex','capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'wage']
df_census = pd.read_csv(url, header=None, skipinitialspace = True, names=labels)
df_census
# Out:
#        age         workclass  fnlwgt        educ  educ_num  \
# 0       39         State-gov   77516   Bachelors        13
# 1       50  Self-emp-not-inc   83311   Bachelors        13
# 2       38           Private  215646     HS-grad         9
# 3       53           Private  234721        11th         7
# 4       28           Private  338409   Bachelors        13
# ...    ...               ...     ...         ...       ...
# 32556   27           Private  257302  Assoc-acdm        12
# 32557   40           Private  154374     HS-grad         9
# 32558   58           Private  151910     HS-grad         9
# 32559   22           Private  201490     HS-grad         9
# 32560   52      Self-emp-inc  287927     HS-grad         9
#
#            marital_status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# 1      Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2                Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3      Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4      Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...                   ...                ...            ...    ...     ...
# 32556  Married-civ-spouse       Tech-support           Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct        Husband  White    Male
# 32558             Widowed       Adm-clerical      Unmarried  White  Female
# 32559       Never-married       Adm-clerical      Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
#
#        capital_gain  capital_loss  hours_per_week native_country   wage
# 0              2174             0              40  United-States  <=50K
# 1                 0             0              13  United-States  <=50K
# 2                 0             0              40  United-States  <=50K
# 3                 0             0              40  United-States  <=50K
# 4                 0             0              40           Cuba  <=50K
# ...             ...           ...             ...            ...    ...
# 32556             0             0              38  United-States  <=50K
# 32557             0             0              40  United-States   >50K
# 32558             0             0              40  United-States  <=50K
# 32559             0             0              20  United-States  <=50K
# 32560         15024             0              40  United-States   >50K
#
# [32561 rows x 15 columns]

# %%
# We count people having a specific occupation
df_census['occupation'].value_counts()
# Out:
# Prof-specialty       4140
# Craft-repair         4099
# Exec-managerial      4066
# Adm-clerical         3770
# Sales                3650
# Other-service        3295
# Machine-op-inspct    2002
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1370
# Farming-fishing       994
# Tech-support          928
# Protective-serv       649
# Priv-house-serv       149
# Armed-Forces            9
# Name: occupation, dtype: int64

# %%
# then we create a rule for referring specific occupations into income groups
# remember to check whether you fucntion capture varians in your data like:
# spelling mistakes, capitalizaiton, abbreviation, etc.

def beslut_indkomstsklasse(var):
    if var.lower() in ['prof-specialty','exec-managerial']:
        return 'High'
    if var in ['Craft-repair']:
        return 'Middel'
    else: 
        return 'Low'

df_census['indkomstklasse'] = df_census['occupation'].apply(beslut_indkomstsklasse)
df_census.head()
# Out:
#    age         workclass  fnlwgt       educ  educ_num      marital_status  \
# 0   39         State-gov   77516  Bachelors        13       Never-married
# 1   50  Self-emp-not-inc   83311  Bachelors        13  Married-civ-spouse
# 2   38           Private  215646    HS-grad         9            Divorced
# 3   53           Private  234721       11th         7  Married-civ-spouse
# 4   28           Private  338409  Bachelors        13  Married-civ-spouse
#
#           occupation   relationship   race     sex  capital_gain  \
# 0       Adm-clerical  Not-in-family  White    Male          2174
# 1    Exec-managerial        Husband  White    Male             0
# 2  Handlers-cleaners  Not-in-family  White    Male             0
# 3  Handlers-cleaners        Husband  Black    Male             0
# 4     Prof-specialty           Wife  Black  Female             0
#
#    capital_loss  hours_per_week native_country   wage indkomstklasse
# 0             0              40  United-States  <=50K            Low
# 1             0              13  United-States  <=50K           High
# 2             0              40  United-States  <=50K            Low
# 3             0              40  United-States  <=50K            Low
# 4             0              40           Cuba  <=50K           High

# %% [markdown]
# # Session 9: Web Scraping
#
# *Nicklas Johansen*

# %% [markdown]
# ## Agenda
#
# In this session you will be introduced to `web scraping`:
# - The Web Scraping Recipe
# - Connecting to the Internet
# - Introduction to HTML
# - Parsing HTML with BeautifulSoup
# - Navigating websites to collect links
# - Ethical Considerations
# - Interactions and Automated Browsing

# %% [markdown]
# ## The Web Scraping Recipe
#
# To scrape information from the web is:
# 1. **MAPPING**: Finding URLs of the pages containing the information you want.
# 2. **DOWNLOAD**: Fetching the pages via HTTP.
# 3. **PARSE**: Extracting the information from HTML.
#
#
# You could also add `connection`, `storing`, `logging`, etc.
#
#
#
# ### Packages used
# Today we will mainly build on the python skills you have gotten so far, and tomorrow we will look into more specialized packages.
#
# * for connecting to the internet we use: **requests**
# * for parsing: **beautifulsoup** and **regex**
# * for automatic browsing / screen scraping: **selenium**
# * for mitigating errors we use: **time**
#
# We will write our scrapers with basic python, for larger projects consider looking into the packages **scrapy**

# %%
# check that you can import these lbraries
# otherwise you they can easily be installed using pip
# example: https://pypi.org/project/beautifulsoup4/

import requests
from bs4 import BeautifulSoup
import re
import selenium
import time
import pandas as pd

# %% [markdown]
# ## Connecting to the Internet
#
#
# **Connecting to the internet** **HTTP**
#
# *URL* : the adressline in our browser.
#
# Via HTTP we send a **get** request to an *address* with *instructions* ( - or rather our dns service provider redirects our request to the right address)
#
# *Address / Domain*: www.google.com
#
# *Instructions*: /search?q=who+is+mister+miyagi
#
# *Header*: information send along with the request, including user agent (operating system, browser), cookies, and prefered encoding.
#
# *HTML*: HyperTextMarkupLanguage the language of displaying web content.

# %%
# DO2021 website
url = 'https://nicklasjohansen.github.io/DO2021'
print(url)
# Out:
# https://nicklasjohansen.github.io/DO2021

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
# Datadrevet Organisationsanalyse
response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE html><html lang="en"><head>\n\n  <meta property="og:title" content="Søg bestyrelsesmedlemmer med markedets bedste filter | nBoard">\n  <meta property="og:description" content="Mangler du et bestyrelses- eller advisory board medlem med de rette kompetencer? Aldrig har kompetencebaseret rekruttering været nemmere.">\n  <meta property="og:image" content="https://s3.eu-central-1.amazonaws.com/nboard.opengraph.banners/default-banner-image.png">\n\n  <!-- Global site tag (gtag.js) - Google Analytics -->\n  <!--\n  <script async src="https://www.googletagmanager.com/gtag/js?id=UA-139093417-1"></script>\n  -->\n\n  <!-- Google Tag Manager -->\n  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n      new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n  })(window,document,\'script\',\'dataLayer\',\'GTM-W3Z8CND\');</script>\n  <!-- End Google Tag Manager -->\n\n  <script>\n    if (document.location.hostname.search("nboard.dk") !== -1) {\n      window.dataLayer = window.dataLayer || [];\n      function gtag() {\n        dataLayer.push(arguments);\n      }\n      gtag(\'js\', new Date());\n    }\n  </script>\n\n  <title>Søg bestyrelsesmedlemmer med markedets bedste filter | nBoard</title>\n\n  <base href="/">\n  <meta name="keywords" content="Søg bestyrelsesmedlem, find bestyrelsesmedlem, kompetencebaseret søgning, find bestyrelsesformand, find medlem til advisory board, bestyrelse, advisory board, medlem til bestyrelse, søg bestyrelseskandidater">\n  <meta charset="utf-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta name="description" content="Mangler du et bestyrelses- eller advisory board medlem med de rette kompetencer? Aldrig har kompetencebaseret rekruttering været nemmere.">\n\n  <link rel="icon" type="image/x-icon" href="favicon.ico">\n  <!-- DO A PROPPER IMPORT -->\n  <link href="https://fonts.googleapis.com/icon?family=Material+Icons" rel="stylesheet">\n  <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.7.2/css/all.css" integrity="sha384-fnmOCqbTlWIlj8LyTjo7mOUStjsKC4pOpQbqyi7RrhN7udi9RwhKkMHpvLbHG9Sr" crossorigin="anonymous">\n  <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/font-awesome/4.5.0/css/font-awesome.min.css">\n\n  <script>\n    var global = global || window;\n    var process = process || {\n        env: {DEBUG: undefined},\n        version: []\n      };\n  </script>\n\n  <style type="text/css">\n    body, html {\n      height: 100%;\n    }\n\n    .app-loading {\n      position: relative;\n      display: flex;\n      flex-direction: column;\n      align-items: center;\n      justify-content: center;\n      height: 100%;\n    }\n\n    .app-loading .spinner {\n      height: 200px;\n      width: 200px;\n      animation: rotate 2s linear infinite;\n      transform-origin: center center;\n      position: absolute;\n      top: 0;\n      bottom: 0;\n      left: 0;\n      right: 0;\n      margin: auto;\n    }\n\n    .app-loading .spinner .path {\n      stroke-dasharray: 1, 200;\n      stroke-dashoffset: 0;\n      animation: dash 1.5s ease-in-out infinite;\n      stroke-linecap: round;\n      stroke: #ddd;\n    }\n\n    @keyframes rotate {\n      100% {\n        transform: rotate(360deg);\n      }\n    }\n\n    @keyframes dash {\n      0% {\n        stroke-dasharray: 1, 200;\n        stroke-dashoffset: 0;\n      }\n      50% {\n        stroke-dasharray: 89, 200;\n        stroke-dashoffset: -35px;\n      }\n      100% {\n        stroke-dasharray: 89, 200;\n        stroke-dashoffset: -124px;\n      }\n    }\n  </style>\n<link rel="stylesheet" href="styles.334655f5f8333abff2b4.css"><style ng-transition="serverApp">@charset "UTF-8";\n.mat-badge-content[_ngcontent-sc0]{font-weight:600;font-size:12px;font-family:Roboto,"Helvetica Neue",san ...

# %% [markdown]
# ## Introduction to HTML
# [What is HTML?](https://www.w3schools.com/whatis/whatis_html.asp)
#
# HTML has a Tree structure.
#
# Each node in the tree has:
# - Children, siblings, parents, descendants.
# - Ids and attributes
#
# <img src="http://www.openbookproject.net/tutorials/getdown/css/images/lesson4/HTMLDOMTree.png"/>

# %% [markdown]
# ### Important syntax and patterns
# _______________
# ```html
# <p>The p tag indicates a paragraph <p/>
# ```
# _______________
# ```html
# <b>The b tag makes the text bold, giving us a clue to its importance </b>
# ```
# output: <b>The b tag makes the text bold, giving us a clue to its importance </b>
# ```html
#
# <em>The em tag emphasize the text</em>, giving us a clue to its importance
# ```
# output: <em>The em tag makes emphasize the text</em>, giving us a clue to its importance
# ___________
# ```html
# <h1>h1</h1><h2>h2</h2><h3>h3</h3><b>Headers give similar clues</b>
# ```
# output:
# <h1>h1</h1><h2>h2</h2><h3>h3</h3><b>Headers give similar clues</b>
#
# ```html
# <a href="www.google.com">The a tag creates a hyperlink <a/>
# ```
# output: <a href="www.google.com">The a tag creates a hyperlink <a/>

# %% [markdown]
# ### How do we find our way around this tree?
# 1. ```BeautifulSoup```: A powerful, principled and readable way to parse data and navigate HTML
# 2. CSS-selectors: Specifying paths using css-selectors, xpath syntax.
# 3. Regex: Extracting string patterns using .split and regular expresssions

# %% [markdown]
# ## Parsing HTML with BeautifulSoup
# BeautifulSoup makes the html tree navigable.
# It allows you to:
# - Search for elements by tag name and/or by attribute.
# - Iterate through them, go up, sideways or down the tree.
# - Furthermore it helps you with standard tasks such as extracting raw text from html, which would be a very tedious task if you had to hardcode it using `.split` commands and using your own regular expressions will be unstable.

# %%
# DO2021 Website using BeautifulSoup
url = 'https://nicklasjohansen.github.io/DO2021/'
response = requests.get(url)
soup = BeautifulSoup(response.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html itemscope="" itemtype="http://schema.org/WebPage" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0" name="viewport"/>
# <title>Datadrevet Organisationsanalyse - Datadrevet Organisationsanalyse</title>
# <meta content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder kursusinformation til det underliggende GitHub repository." name="description"/>
# <meta content="Nicklas Johansen" name="author"/><script type="application/ld+json">
# {
#     "@context": "http://schema.org",
#     "@type": "WebSite",
#     "name": "Datadrevet Organisationsanalyse",
#
#     "url": "https:\/\/nicklasjohansen.github.io\/DO2021\/"
# }
# </script><script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "name": "",
#   "url": "https:\/\/nicklasjohansen.github.io\/DO2021\/"
#
#
#
#
# }
# </script>
# <meta content="Datadrevet Organisationsanalyse" property="og:title"/>
# <meta content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder kursusinformation til det underliggende GitHub repository." property="og:description"/>
# <meta content="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png" property="og:image"/>
# <meta content="https://nicklasjohansen.github.io/DO2021/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="Datadrevet Organisationsanalyse" property="og:site_name"/>
# <meta content="Datadrevet Organisationsanalyse" name="twitter:title"/>
# <meta content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder …" name="twitter:description"/>
# <meta content="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png" name="twitter:image"/>
# <meta content="summary" name="twitter:card"/>
# <link href="https://nicklasjohansen.github.io/DO2021/img/favicon.ico" rel="icon" type="image/x-icon"/>
# <meta content="Hugo 0.86.1" name="generator"/>
# <link href="https://nicklasjohansen.github.io/DO2021/index.xml" rel="alternate" title="Datadrevet Organisationsanalyse" type="application/rss+xml"/><link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.10.0/katex.min.css" integrity="sha384-9eLZqc9ds8eNjO3TmqPeYcDj8n+Qfa4nuSiGYa6DjLNcv9BtN69ZIulL9+8CqC9Y" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" rel="stylesheet"/><link href="https://nicklasjohansen.github.io/DO2021/css/main.css" rel="stylesheet"/><link href="https://fonts.googleapis.com/css?family=Lora:400,700,400italic,700italic" rel="stylesheet"/>
# <link href="https://fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800" rel="stylesheet"/><link href="https://nicklasjohansen.github.io/DO2021/css/syntax.css" rel="stylesheet"/><link href="https://nicklasjohansen.github.io/DO2021/css/codeblock.css" rel="stylesheet"/><link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/photoswipe/4.1.2/photoswipe.min.css" integrity="sha384-h/L2W9KefUClHWaty3SLE5F/qvc4djlyR4qY3NUV5HGQBBW7stbcfff1+I/vmsHh" rel="stylesheet"/>
# <link crossorigin="anonymous" href="https://cdnjs.cloudflare.com/ajax/libs/photoswipe/4.1.2/default-skin/default-skin.min.css" integrity="sha384-iD0dNku6PYSIQLyfTOpB06F2KCZJAKLOThS5HRe8b3ibhdEQ6eKsFf/EeFxdOt5R" rel="stylesheet"/>
# </head>
# <body>
# <nav class="navbar navbar-default navbar-fixed-top navbar-custom">
# <div class="container-fluid">
# <div class="navbar-header">
# <button class="navbar-toggle" data-target="#main-navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="https://nicklasjohansen.github.io/DO2021/">Datadrevet Organisationsanalyse</a>
# </div>
# <div class="collapse navbar-collapse" id="main-navbar">
# <ul class="nav navbar-nav navbar-right">
# <li>
# <a href="/DO2021/" title="Home">Home</a>
# </li>
# <li class="navlinks-container">
# <a class="navlinks-parent">Posts</a>
# <div class="navlinks-children">
# <a href="/DO2021/post/cases/">Cases</a>
# <a href="/DO2021/post/velkommen/">Velkommen</a>
# <a href="/DO2021/post/install/">Install</a>
# <a href="/DO2021/post/assignments/">Assignments</a>
# <a href="/DO2021/post/eksamen/">Eksamen</a>
# </div>
# </li>
# <li>
# <a href="/DO2021/page/l%c3%a6sning/" title="Læsning">Læsning</a>
# </li>
# <li>
# <a href="/DO2021/page/tidsplan/" title="Tidsplan">Tidsplan</a>
# </li>
# </ul>
# </div>
# <div class="avatar-container">
# <div class="avatar-img-border">
# <a href="https://nicklasjohansen.github.io/DO2021/" title="Datadrevet Organisationsanalyse">
# <img alt="Datadrevet Organisationsanalyse" class="avatar-img" src="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png"/>
# </a>
# </div>
# </div>
# </div>
# </nav>
# <div aria-hidden="true" class="pswp" role="dialog" tabindex="-1">
# <div class="pswp__bg"></div>
# <div class="pswp__scroll-wrap">
# <div class="pswp__container">
# <div class="pswp__item"></div>
# <div class="pswp__item"></div>
# <div class="pswp__item"></div>
# </div>
# <div class="pswp__ui pswp__ui--hidden">
# <div class="pswp__top-bar">
# <div class="pswp__counter"></div>
# <button class="pswp__button pswp__button--close" title="Close (Esc)"></button>
# <button class="pswp__button pswp__button--share" title="Share"></button>
# <button class="pswp__button pswp__button--fs" title="Toggle fullscreen"></button>
# <button class="pswp__button pswp__button--zoom" title="Zoom in/out"></button>
# <div class="pswp__preloader">
# <div class="pswp__preloader__icn">
# <div class="pswp__preloader__cut">
# <div class="pswp__preloader__donut"></div>
# </div>
# </div>
# </div>
# </div>
# <div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
# <div class="pswp__share-tooltip"></div>
# </div>
# <button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)">
# </button>
# <button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)">
# </button>
# <div class="pswp__caption">
# <div class="pswp__caption__center"></div>
# </div>
# </div>
# </div>
# </div>
# <header class="header-section">
# <div class="intro-header no-img">
# <div class="container">
# <div class="row">
# <div class="col-lg-8 col-lg-offset-2 col-md-10 col-md-offset-1">
# <div class="page-heading">
# <h1>Datadrevet Organisationsanalyse</h1>
# <hr class="small"/>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div class="container" role="main">
# <div class="row">
# <div class="col-lg-8 col-lg-offset-2 col-md-10 col-md-offset-1">
# <div class="well">
# <p><a href="https://kurser.ku.dk/course/astk18379u/2021-2022">Datadrevet Organisationsanalyse</a> afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det <a href="https://polsci.ku.dk/">Institut for Statskundskab</a> ved Københavns Universitet. Denne side indeholder kursusinformation til det underliggende <a href="https://github.com/NicklasJohansen/DO2021">GitHub repository</a>.</p>
# </div>
# <div class="posts-list">
# <article class="post-preview">
# <a href="https://nicklasjohansen.github.io/DO2021/post/cases/">
# <h2 class="post-title">Cases</h2>
# </a>
# <p class="post-meta">
# <span class="post-meta">
# <i class="fas fa-calendar"></i>
#
#
#
#
#
#        | <i class="fas fa-user"></i> Nicklas Johansen
#
#
#
# </span>
# </p>
# <div class="post-entry">
#
#         Datadrevet Organisationsanalyse giver dig mulighed for at arbeje med rigtige organisationer og deres problemstillinger. Et caseforløb er struktureret således:
#  Organisationen kommer på besøg i undervisningen. Cases præsenteres og data stiles til rådighed. Styregruppemøde afholdes virtuelt mellem studerende og caseorganisation. Udvalgte grupper præsenteres deres caseløsninger foran dommerpanel fra caseorganisationen.  Vi forventer at alle grupper forsøger at løse casen. En løsning består af en powerpoint-præsentation (brug udleveret template) samt en jupyter notebook.
#         <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/cases/">[Read More]</a>
# </div>
# </article>
# <article class="post-preview">
# <a href="https://nicklasjohansen.github.io/DO2021/post/velkommen/">
# <h2 class="post-title">Velkommen</h2>
# </a>
# <p class="post-meta">
# <span class="post-meta">
# <i class="fas fa-calendar"></i>
#
#
#
#
#
#        | <i class="fas fa-user"></i> Nicklas Johansen
#
#
#
# </span>
# </p>
# <div class="post-entry">
#
#         Velkommen til Datadrevet Organisationsanalyse. Vi har brugt et år på at udvikle faget og har store ambitioner. Vi håber at det bliver sjovt, lærerrigt og alt i alt et fedt fag i vil huske tilbage på. Vi har forsøgt at prioritere tværfaglighed i pensum, gruppedannelse og i de metoder vi kommer til at anvende i faget.
# Undervisningen finder sted om onsdagen i lokale CSS 35-01-06 (Center for Sundhed og Samfund, bygning 35, kælder, lokale 6) i tidsrummet 13:15-15:00.
#         <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/velkommen/">[Read More]</a>
# </div>
# </article>
# <article class="post-preview">
# <a href="https://nicklasjohansen.github.io/DO2021/post/install/">
# <h2 class="post-title">Install</h2>
# </a>
# <p class="post-meta">
# <span class="post-meta">
# <i class="fas fa-calendar"></i>
#
#
#
#
#
#        | <i class="fas fa-user"></i> Nicklas Johansen
#
#
#
# </span>
# </p>
# <div class="post-entry">
#
#         Vi kommer til at kode en masse til Datadrevet Organisationsanalyse, hvorfor vi får brug for en masse værktøjer:
#  Python Jupyter Notebook Github  Vi forventer at du har installeret værktøjerne inden første forelæsning. Brug vores vejledninger eller fremsøg anden hjælp på google.
#  Python Python er et gratis programmeringssprog. Vi kommer til at bruge Python version 3.7 (eller højere).
# Du kan installere Python ved at installere Anaconda på dette link.
#         <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/install/">[Read More]</a>
# </div>
# </article>
# <article class="post-preview">
# <a href="https://nicklasjohansen.github.io/DO2021/post/assignments/">
# <h2 class="post-title">Assignments</h2>
# </a>
# <p class="post-meta">
# <span class="post-meta">
# <i class="fas fa-calendar"></i>
#
#
#
#
#
#        | <i class="fas fa-user"></i> Nicklas Johansen
#
#
#
# </span>
# </p>
# <div class="post-entry">
#
#         Det er vigtigt at du forbereder dig til dette kursus. Vi har forsøgt at designe et fedt kursus således at alle der vil kan klare sig godt, men det kræver fordybelse, især hvis du aldrig har haft et universitetskursus i organisationsteori og/eller python. Herunder kan du læse om kursets større opgaver, også kaldet for assignments. Man kan godt gå til eksamen uden at løse assignments, men vi anbefaler at man forsøger at bestå alle assignments.
#         <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/assignments/">[Read More]</a>
# </div>
# </article>
# <article class="post-preview">
# <a href="https://nicklasjohansen.github.io/DO2021/post/eksamen/">
# <h2 class="post-title">Eksamen</h2>
# </a>
# <p class="post-meta">
# <span class="post-meta">
# <i class="fas fa-calendar"></i>
#
#
#
#
#
#        | <i class="fas fa-user"></i> Nicklas Johansen
#
#
#
# </span>
# </p>
# <div class="post-entry">
#
#         I starten af semesteret vil I blive inddelt i grupper. Disse grupper skaber fundamentet for samarbejde til undervisningsgange såvel som jeres eksamensprojekt.
# Det forventes, at I afleverer en skriftlig opgave, hvor I har analyseret en selvvalgt organisatorisk problemstilling med tilhørende dataindsamling, dataanalyse, metodevalg osv. Derudover forventes det, at I vedlægger jeres kode som bilag.
# Deadline for aflevering af ordinær eksamen): 3. januar 2022 kl. 12.00.
# Offentliggørelse af karakterer: 25. januar 2022 kl.
#         <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/eksamen/">[Read More]</a>
# </div>
# </article>
# </div>
# </div>
# </div>
# </div>
# <div class="page-meta">
# </div>
# <footer>
# <div class="container">
# <div class="row">
# <div class="col-lg-8 col-lg-offset-2 col-md-10 col-md-offset-1">
# <ul class="list-inline text-center footer-links">
# <li>
# <a href="mailto:nj@sodas.ku.dk" title="Email me">
# <span class="fa-stack fa-lg">
# <i class="fas fa-circle fa-stack-2x"></i>
# <i class="fas fa-envelope fa-stack-1x fa-inverse"></i>
# </span>
# </a>
# </li>
# </ul>
# <p class="credits copyright text-muted">
# <a href="https://nicklasjohansen.netlify.app/">Nicklas Johansen</a>
#
#
#
#            • ©
#
#             2021
#
#
#
#              •
#             <a href="https://nicklasjohansen.github.io/DO2021/">Datadrevet Organisationsanalyse</a>
# </p>
# <p class="credits theme-by text-muted">
# <a href="https://gohugo.io">Hugo v0.86.1</a> powered  •  Theme <a href="https://github.com/halogenica/beautifulhugo">Beautiful Hugo</a> adapted from <a href="https://deanattali.com/beautiful-jekyll/">Beautiful Jekyll</a>
# </p>
# </div>
# </div>
# </div>
# </footer><script crossorigin="anonymous" integrity="sha384-K3vbOmF2BtaVai+Qk37uypf7VrgBubhQreNQe9aGsz9lB63dIFiQVlJbr92dw2Lx" src="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.10.0/katex.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-kmZOZB5ObwgQnS/DuDg6TScgOiWWBiVt0plIRkZCmE6rDZGrEOQeHM5PcHi+nyqe" src="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.10.0/contrib/auto-render.min.js"></script>
# <script crossorigin="anonymous" integrity="sha256-ZosEbRLbNQzLpnKIkEdrPv7lOy9C27hHQ+Xp8a4MxAQ=" src="https://code.jquery.com/jquery-1.12.4.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-Tc5IQib027qvyjSMfHjOMaLkfuWVxZxUPnCJA7l2mCWNIpG9mGCD8wGNIcPD7Txa" src="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/js/bootstrap.min.js"></script>
# <script src="https://nicklasjohansen.github.io/DO2021/js/main.js"></script><script> renderMathInElement(document.body); </script><script crossorigin="anonymous" integrity="sha384-QELNnmcmU8IR9ZAykt67vGr9/rZJdHbiWi64V88fCPaOohUlHCqUD/unNN0BXSqy" src="https://cdnjs.cloudflare.com/ajax/libs/photoswipe/4.1.2/photoswipe.min.js"></script>
# <script crossorigin="anonymous" integrity="sha384-m67o7SkQ1ALzKZIFh4CiTA8tmadaujiTa9Vu+nqPSwDOqHrDmxLezTdFln8077+q" src="https://cdnjs.cloudflare.com/ajax/libs/photoswipe/4.1.2/photoswipe-ui-default.min.js"></script><script src="https://nicklasjohansen.github.io/DO2021/js/load-photoswipe.js"></script>
# </body>
# </html>

# %%
# DO2021 Website without using BeautifulSoup
response = requests.get(url)
response.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" itemscope itemtype="http://schema.org/WebPage">\n  <head>\n    \n\n  <meta charset="utf-8" />\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">\n\n  <title>Datadrevet Organisationsanalyse - Datadrevet Organisationsanalyse</title>\n  <meta name="description" content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder kursusinformation til det underliggende GitHub repository.">\n  <meta name="author" content="Nicklas Johansen"/><script type="application/ld+json">\n{\n    "@context": "http://schema.org",\n    "@type": "WebSite",\n    "name": "Datadrevet Organisationsanalyse",\n    \n    "url": "https:\\/\\/nicklasjohansen.github.io\\/DO2021\\/"\n}\n</script><script type="application/ld+json">\n{\n  "@context": "http://schema.org",\n  "@type": "Organization",\n  "name": "",\n  "url": "https:\\/\\/nicklasjohansen.github.io\\/DO2021\\/"\n  \n  \n  \n  \n}\n</script>\n\n<meta property="og:title" content="Datadrevet Organisationsanalyse" />\n<meta property="og:description" content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder kursusinformation til det underliggende GitHub repository.">\n<meta property="og:image" content="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png" />\n<meta property="og:url" content="https://nicklasjohansen.github.io/DO2021/" />\n<meta property="og:type" content="website" />\n<meta property="og:site_name" content="Datadrevet Organisationsanalyse" />\n\n  <meta name="twitter:title" content="Datadrevet Organisationsanalyse" />\n  <meta name="twitter:description" content="Datadrevet Organisationsanalyse afholdes for første gang i efteråret 2021. Det er et valgfag der udbydes på det Institut for Statskundskab ved Københavns Universitet. Denne side indeholder …">\n  <meta name="twitter:image" content="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png" />\n  <meta name="twitter:card" content="summary" />\n  <link href=\'https://nicklasjohansen.github.io/DO2021/img/favicon.ico\' rel=\'icon\' type=\'image/x-icon\'/>\n  <meta name="generator" content="Hugo 0.86.1" />\n  <link rel="alternate" href="https://nicklasjohansen.github.io/DO2021/index.xml" type="application/rss+xml" title="Datadrevet Organisationsanalyse"><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/KaTeX/0.10.0/katex.min.css" integrity="sha384-9eLZqc9ds8eNjO3TmqPeYcDj8n+Qfa4nuSiGYa6DjLNcv9BtN69ZIulL9+8CqC9Y" crossorigin="anonymous">\n  <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.5.0/css/all.css" integrity="sha384-B4dIYHKNBt8Bc12p+WXckhzcICo0wtJAoU8YZTY5qE0Id1GSseTk6S+L3BlXeVIU" crossorigin="anonymous">\n  <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.7/css/bootstrap.min.css" integrity="sha384-BVYiiSIFeK1dGmJRAkycuHAHRg32OmUcww7on3RYdg4Va+PmSTsz/K68vbdEjh4u" crossorigin="anonymous"><link rel="stylesheet" href="https://nicklasjohansen.github.io/DO2021/css/main.css" /><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Lora:400,700,400italic,700italic" />\n  <link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Open+Sans:300italic,400italic,600italic,700italic,800italic,400,300,600,700,800" /><link rel="stylesheet" href="https://nicklasjohansen.github.io/DO2021/css/syntax.css" /><link rel="stylesheet" href="https://nicklasjohansen.github.io/DO2021/css/codeblock.css" /><link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/photoswipe/4.1.2/photoswipe.min.css" integrity="sha384-h/L2W9KefUClHWaty3SLE5F/qvc4djlyR4qY3NUV5HGQBBW7stbcfff1+I/vmsHh" crossorigin="anonymous">\n  <link rel="stylesheet" href="https://cdnjs.c ...

# %%
print(type(response.text))
print(type(soup))
# Out:
# <class 'str'>
# <class 'bs4.BeautifulSoup'>

# %%
soup.find_all('h1')
# Out:
# [<h1>Datadrevet Organisationsanalyse</h1>]

# %%
soup.find_all('h2')
# Out:
# [<h2 class="post-title">Cases</h2>,
#  <h2 class="post-title">Velkommen</h2>,
#  <h2 class="post-title">Install</h2>,
#  <h2 class="post-title">Assignments</h2>,
#  <h2 class="post-title">Eksamen</h2>]

# %%
soup.find_all('h2')[0].text.strip()
# Out:
# 'Cases'

# %%
soup.find_all('a')
# Out:
# [<a class="navbar-brand" href="https://nicklasjohansen.github.io/DO2021/">Datadrevet Organisationsanalyse</a>,
#  <a href="/DO2021/" title="Home">Home</a>,
#  <a class="navlinks-parent">Posts</a>,
#  <a href="/DO2021/post/cases/">Cases</a>,
#  <a href="/DO2021/post/velkommen/">Velkommen</a>,
#  <a href="/DO2021/post/install/">Install</a>,
#  <a href="/DO2021/post/assignments/">Assignments</a>,
#  <a href="/DO2021/post/eksamen/">Eksamen</a>,
#  <a href="/DO2021/page/l%c3%a6sning/" title="Læsning">Læsning</a>,
#  <a href="/DO2021/page/tidsplan/" title="Tidsplan">Tidsplan</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/" title="Datadrevet Organisationsanalyse">
#  <img alt="Datadrevet Organisationsanalyse" class="avatar-img" src="https://nicklasjohansen.github.io/DO2021/img/ku_logo_uk_v.png"/>
#  </a>,
#  <a href="https://kurser.ku.dk/course/astk18379u/2021-2022">Datadrevet Organisationsanalyse</a>,
#  <a href="https://polsci.ku.dk/">Institut for Statskundskab</a>,
#  <a href="https://github.com/NicklasJohansen/DO2021">GitHub repository</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/post/cases/">
#  <h2 class="post-title">Cases</h2>
#  </a>,
#  <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/cases/">[Read More]</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/post/velkommen/">
#  <h2 class="post-title">Velkommen</h2>
#  </a>,
#  <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/velkommen/">[Read More]</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/post/install/">
#  <h2 class="post-title">Install</h2>
#  </a>,
#  <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/install/">[Read More]</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/post/assignments/">
#  <h2 class="post-title">Assignments</h2>
#  </a>,
#  <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/assignments/">[Read More]</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/post/eksamen/">
#  <h2 class="post-title">Eksamen</h2>
#  </a>,
#  <a class="post-read-more" href="https://nicklasjohansen.github.io/DO2021/post/eksamen/">[Read More]</a>,
#  <a href="mailto:nj@sodas.ku.dk" title="Email me">
#  <span class="fa-stack fa-lg">
#  <i class="fas fa-circle fa-stack-2x"></i>
#  <i class="fas fa-envelope fa-stack-1x fa-inverse"></i>
#  </span>
#  </a>,
#  <a href="https://nicklasjohansen.netlify.app/">Nicklas Johansen</a>,
#  <a href="https://nicklasjohansen.github.io/DO2021/">Datadrevet Organisationsanalyse</a>,
#  <a href="https://gohugo.io">Hugo v0.86.1</a>,
#  <a href="https://github.com/halogenica/beautifulhugo">Beautiful Hugo</a>,
#  <a href="https://deanattali.com/beautiful-jekyll/">Beautiful Jekyll</a>]

# %%
soup.find_all('a')[0].get('href')
# Out:
# 'https://nicklasjohansen.github.io/DO2021/'

# %% [markdown]
# ## Navigating websites to collect links
# Now I will show you a few common ways of finding the links to the pages you want to scrape.
#
# ### Building URLS using a recognizable pattern.
# A nice trick is to understand how urls are constructed to communicate with a server.
#
# Lets look at how [jobindex.dk](https://www.jobindex.dk/) does it. We simply click around and take note at how the addressline changes.
#
# This will allow us to navigate the page, without having to parse information from the html or click any buttons.
#
# * / is like folders on your computer.
# * ? entails the start of a query with parameters
# * = defines a variable: e.g. page=1000 or offset = 100 or showNumber=20
# * & separates different parameters.
# * \+ is html for whitespace

# %%
# Mapping exercise
url = 'https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&q=python'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="da-DK">
# <head>
# <title>Ledige job - Python - Storkøbenhavn, side 3 ud af 7 | Jobindex</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <link href="/res/bootstrap-multiselect/dist/css/bootstrap-multiselect.css?h=6a6b68a249811e054fa8d759452816a9248c0748" rel="stylesheet"/><link href="/res/select2/dist/css/select2.min.css?h=a170ecdd58f00519741ed4b63abc064ef35db1a9" rel="stylesheet"/><link href="/res/bootstrap-datepicker/dist/css/bootstrap-datepicker3.standalone.min.css?h=f02cbfe4614ade97b3e5823be92702ae7bd445cd" rel="stylesheet"/><link href="/res/mapbox-gl/dist/mapbox-gl.css?h=0221a0dab467f93c80e8f5264c4f146e6d11496d" rel="stylesheet"/><link href="/res/font-awesome/css/font-awesome.css?h=ee906a8196d0fbd581c27a9d5615db4c250860f2" rel="stylesheet"/><link href="/css/_scss/fonts/roboto.css?h=e5bcd6527330b9ea940dd0de1cc29edbdd15519b" rel="stylesheet"/><link href="/css/_scss/fonts/frank_ruhl_libre.css?h=f908f8924442cd3fc8a7a73091bace3860f3d8a2" rel="stylesheet"/><link href="/css/_scss/themes/jobindex.css?h=072408a1b9c7f05731fd898536b8235d1a0dd8c4" rel="stylesheet"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/><meta content="da-DK" http-equiv="content-language"/>
# <meta content="width=device-width, initial-scale=1, viewport-fit=cover" name="viewport"/><meta content="none" name="msapplication-config"/><meta content="#b41018" name="theme-color"/>
# <meta content="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python" property="og:url"/>
# <link href="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python" rel="canonical"/>
# <link href="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python&amp;lang=da" hreflang="da" rel="alternate"/>
# <link href="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python&amp;lang=en" hreflang="en" rel="alternate"/>
# <link href="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python" hreflang="x-default" rel="alternate"/>
# <link href="/jobsoegning?geoareaid=15182&amp;q=python&amp;format=xml" rel="alternate nofollow" title="Ledige job i Storkøbenhavn indeholdende ordet python" type="application/rss+xml"/>
# <script>//<![CDATA[
#
#     window.JIX = window.JIX || {};
#     (function () {
#         'use strict';
#         if (window.JIX.CookieConsent) {
#             return;
#         }
#
#         function required(cat) {
#             return ["necessary"].indexOf(cat) >= 0;
#         }
#         // In case an ad blocker rejects our real implementation, we'll just do nothing and leave people alone.
#         window.JIX.CookieConsent = {
#             hasConsent: function (cat) { return new Promise(function (resolve) { resolve(required(cat)) }); },
#             whenConsent: function (cat, f) { if (required(cat)) { f(); } },
#         };
#     })();
#
# //]]></script>
# <script>//<![CDATA[
#
#     var Stash = {"common":{"companyuserid":null,"csrf_token":"6520f3fa50b95565c552a2473b9364dd5d3a98c6","lang":"da","site":"jobdk","sitename":"Jobindex","sitename_genitive":"Jobindex'","userid":null},"cookie_consent":{"categories":[{"key":"necessary","required":true,"title":"Nødvendige"},{"key":"statistics","required":false,"title":"Statistik"},{"key":"marketing","required":false,"title":"Markedsføring"}],"cookieOptions":{"domain":".jobindex.dk","maxAge":31536000,"name":"jix-consent","path":"\/","secure":true},"currentVersion":1,"latestTermsVersion":182,"options":{"enableAutoOpen":true,"enableBox":true,"modalCss":[],"sandbox":false},"urls":{"logConsent":"\/api\/cookie-consent\/v1\/log"}},"jobagent\/popup":{"formSelector":"#jobagent_form"},"jobsearch":{"form_options":{"api":{"find_company":"\/jobagent\/virksomhed"},"archive":{"maxdate":20211110,"mindate":20210810},"enable_advanced":true}},"jobsearch\/saved_search":{"formSelector":"#save_search_form"},"jobsearch\/search":{"ajax_error_text":"Noget gik galt med jobsøgningen. Prøv igen.","callbacks":{"load":"\/jobsoegning.json"},"user":"jobdk"},"login":{"api_urls":{"check":{"companyuser":"\/api\/login\/companyuser\/check","user":"\/api\/login\/user\/check"},"companyuser":"\/api\/login\/companyuser","forms":{"companyuser":"\/api\/login\/companyuser\/form","user":"\/api\/login\/user\/form"},"user":"\/api\/login\/user"},"callbacks":{},"forms":{"companyuser":null,"user":null},"redirect":{"companyuser":"\/jobsoegning\/storkoebenhavn?page=3&q=python&geoareaid=15182","user":"\/jobsoegning\/storkoebenhavn?page=3&q=python&geoareaid=15182"}},"sentry":{"config":{"dsn":"https:\/\/43e741b0ae4b427298ec07cf968d43c0@sentry.jobindex.dk\/2","environment":"production","release":"03e3aab1849e314e6b409db2b1680523a6e17371"},"page_load_time":1636548050000,"tags":{"request.id":"f216f317710d8b143a97f9efe89b02da","site":"jobdk"}},"widgets\/jix_slider":[{"id":"widgets_jix_slider_0","stash":{"id":"radius_slider"}}]};
#
# //]]></script>
# <script>//<![CDATA[
#
#     var jix_script_errors = [];
#     var jix_script_load_start = +new Date();
#     jix_handle_script_error = function(ev) {
#         var now  = +new Date();
#         jix_script_errors.push({ src: ev && ev.target.src, time: now - jix_script_load_start });
#     };
#
# //]]></script> <script onerror="jix_handle_script_error(event)" src="/js/dist/manifest.bundle.js?h=b560feff136143e8c8fd36e4e4ecf2f92edc78a4"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/dist/polyfills.bundle.js?h=f5b6b4f8328f2505c96dc950a13826334f4cd340"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/dist/vendors~adm/address~adm/bookmedia/default~3b344164.bundle.js?h=ffb814aa6f8addccdc109fc0c2c8ac0ce29a636e"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/dist/vendors~sentry.bundle.js?h=0ccca6a68fc456343160209614823729be3370b1"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/dist/sentry.bundle.js?h=f274515797aec0dedce4806b6c315ff6251aed2c"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/jquery/dist/jquery.min.js?h=644d35e274fd64ddaf6d12af813e820c424176a9"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/jquery-migrate/dist/jquery-migrate.js?h=2e4bde47fb4c9de9d2393917294e009560987cfb"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/dist/gettext.bundle.js?h=be48f9e3d0a661be7618f52b54cf68dcdb0f448c"></script>
# <script onerror="jix_handle_script_error(event)" src="/api/gettext/da_DK/jobsearch.js?h=e51f9b0a965cef883c8df170715727855384ff01-6a148bc52ae1aeea9cacedc0a1d31b44ee79e356"></script>
# <script onerror="jix_handle_script_error(event)" src="/api/gettext/da_DK/geo.js?h=4fd27f67a3432deb1405265dd28e88776c6d0bf5-6a148bc52ae1aeea9cacedc0a1d31b44ee79e356"></script>
# <script onerror="jix_handle_script_error(event)" src="/api/gettext/da_DK/global.js?h=41b691bf4530c459e85f7fec920c6a3661946ac5-6a148bc52ae1aeea9cacedc0a1d31b44ee79e356"></script>
# <script onerror="jix_handle_script_error(event)" src="/api/gettext/da_DK/email_suggestions.js?h=bfde72e3aa419cc0a8774e4a00fe6152c63f7896-6a148bc52ae1aeea9cacedc0a1d31b44ee79e356"></script>
# <script onerror="jix_handle_script_error(event)" src="/api/gettext/da_DK/userterms.js?h=92fcae9961f511676a57ec6575b6e280b248633d-6a148bc52ae1aeea9cacedc0a1d31b44ee79e356"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/customlayout~jobagent/show~jobsearch/sear~9ce0dedf.bundle.js?h=f5915e269e1cde00fc127310c76477e94d7b4850"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/blockui/jquery.blockUI.js?h=cce1e767f1684d0fbd8de1ea9cfb7963f984a3ad"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/popper.js/dist/umd/popper.min.js?h=bb1aaae3e862ff99323a902212a0962f55de0705"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/bootstrap/dist/js/bootstrap.min.js?h=44d24b32ffc16f46a62639c4cbaa6868c3a82354"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/bootbox/dist/bootbox.all.min.js?h=06b822698a0d05d396ec93d65145181d593a1620"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/bootstrap-multiselect/dist/js/bootstrap-multiselect.min.js?h=67812fa6cc7a8600f7d9dcdad591165aeb416055"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/jobsearch/search.bundle.js?h=f89052e6ee235bf485032304d5140e06d5585606"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/select2/dist/js/select2.full.min.js?h=2905227ca07c288bbe0fa1695c29656d565512f0"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/select2/dist/js/i18n/da.js?h=f099692725d479e27db31a3fd76e90fb725cee0b"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_select2.js?h=fedb59903114316560d0f77629bb42d82168bed9"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_geoarea.js?h=654aabb34d06aef861b4d2186bc6d6de9c58c32e"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/georadius.bundle.js?h=0112bbed82b2c35c056c2ead059f66d809b82567"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/widgets/jix_slider.bundle.js?h=826e6fe6cfe79814dc4000fafb5ad27c44c64dfd"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/bootstrap-datepicker/dist/js/bootstrap-datepicker.min.js?h=3ea8fa0d338925bfd0a8d31759ba3b4cee226297"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/bootstrap-datepicker/dist/locales/bootstrap-datepicker.da.min.js?h=66dcc5490971fb7694b0132b94c3ac2d036f57d3"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_datepicker.js?h=c98b1d6993e0277181b3dbd86e6c6c509fb425be"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_preventdoublesubmit.js?h=3f3ff09f54bba9691be73e9099630669d95d44ff"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/jobsearch.bundle.js?h=fa9134fb733f6bcd08eaba925ea62b013826f229"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/vendors~jobagent/edit_agent~jobsearch/map~8f99bde6.bundle.js?h=93c2fe1e4a41c57552745bcc7ad99377aec6ac3b"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/mapbox-gl/dist/mapbox-gl.js?h=e755a1564839bf0da590a2979cfeef44c0faf47e"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/jobsearch/radius_map.bundle.js?h=8ff98408487397339d20a65562fea775c5d429f9"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/jobsearch/saved_search.bundle.js?h=75189a5bfbf5310b8ddb26873dadba26b8bb3038"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/jobagent/popup.bundle.js?h=cfcaa99def1bbdad5a3636c5efdd8694b88fdbf9"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/email-autocomplete/dist/jquery.email-autocomplete.min.js?h=8db40ac26727217bcb8456391ef3433954cb5148"></script>
# <script onerror="jix_handle_script_error(event)" src="/res/mailcheck/src/mailcheck.min.js?h=3f58378431dfb989463f5744728a767f905431a0"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_email_field/domains_jobdk.js?h=982bad35449a16c42ec6d6c9166e4f536a4e594b"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/jix_email_field.js?h=d13bf1142ef14bc4e2f9d895db5dca9881ee34e1"></script>
# <script onerror="jix_handle_script_error(event)" src="/js/companyindex2.js?h=54371c67e70e4db4e75f3d01b6b841e19d18d4f5"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/company_follow.bundle.js?h=494665298c996bda77830bb2e04abbb5a5b831f3"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/global.bundle.js?h=499dd2fe6c6d493215e59e316d7e4163f0cce817"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/clickexpose.js?h=15944cd37d9debfbee6412f016dc5787c8e6c979"></script>
# <script src="/js/dist/cookie_consent.bundle.js?h=1102e871999914b91553ad9212e04a04e139a5b8"></script>
# <script defer="" onerror="jix_handle_script_error(event)" src="/js/dist/login.bundle.js?h=2d050c9c54faa9dea5c2949a45b0cfb73769222d"></script>
# <script>//<![CDATA[
#
#     if (jix_script_errors.length > 0) {
#         var now  = +new Date();
#         var offset = now - jix_script_load_start;
#         var errors = jix_script_errors;
#         jix_script_errors = [];
#         if (errors.length >= 5) {
#             Sentry.captureMessage("Failed to load 5 or more scripts", {
#                 level: 'error',
#                 extra: {
#                     scripts: errors,
#                     load_time: offset
#                 }
#             });
#         } else {
#             errors.forEach(function(script) {
#                 var name = script.src.replace(/\?.*/, '');
#                 Sentry.captureMessage("Failed to load " + name, {
#                     level: 'error',
#                     extra: {
#                         script: script,
#                         load_time: offset
#                     }
#                 });
#             });
#         }
#         jix_script_errors = errors;
#     }
#
# //]]></script>
# <script type="text/javascript">
# window.ga=window.ga||function(){(ga.q=ga.q||[]).push(arguments)};ga.l=+new Date;
# ga('create', "UA-16861578-4", "jobindex.dk");
# // Censor some information:
# var gaurl = ['address', 'email'].reduce(function (url, key) {
#     return url.replace(new RegExp("(\\\?.*?" + key + "=)([^&]*)"), '\$1***');
# }, "https:\/\/www.jobindex.dk\/jobsoegning\/storkoebenhavn?page=3&q=python");
# ga('set', 'location', gaurl);
# var ga_enable_advertising;
# JIX.CookieConsent.hasConsent('marketing').then(function (consented) {
#     ga_enable_advertising = consented;
# });
# JIX.CookieConsent.whenConsent('statistics', function () {
#     if (ga_enable_advertising) {
#         ga('require', 'displayfeatures');
#     } else {
#         ga('set', 'allowAdFeatures', false);
#     }
#     ga('set', 'anonymizeIp', true);
#     ga('send', 'pageview', {"dimension1":0,"dimension2":0});
#
#     var script = document.createElement('script');
#     script.async = true;
#     script.src = 'https://www.google-analytics.com/analytics.js';
#     document.head.appendChild(script);
# });
# </script>
# </head>
# <body class="jix jix_bootstrap jix_design_jobindex jix_design_jobdk jix_design_jobindex20 jix_bootstrap_active jix-jobseeker">
# <div class="site-wrapper">
# <header class="site-header" role="banner">
# <div class="top-header">
# <div class="container">
# <div class="row align-items-center">
# <div class="col-3 col-sm-2 d-lg-none">
# <div class="hamburger-container">
# <button aria-label="Menu" class="hamburger hamburger--squeeze" type="button"><span class="hamburger-box"><span class="hamburger-inner"></span></span></button>
# </div>
# </div>
# <div class="col-6 col-sm-8 col-lg-6">
# <div class="d-flex">
# <div class="flex-grow-1 flex-lg-shrink-1 flex-lg-grow-0">
# <a class="logo" href="/" title="Jobindex forside">
# <img alt="Jobindex" src="/img/jobindex20/logo/jobindex_white.svg"/>
# </a> </div>
# <div class="counter-wrapper d-none d-lg-flex">
# <a data-click-label="x job i dag" href="/jobsoegning/analyse-kilder">
# <span>45.000</span> job i dag
# </a>
# </div>
# </div>
# </div>
# <div class="col mx-lg-nl d-none d-lg-block">
# <nav class="service">
# <ul>
# <li class="active">
# <a class="audience-link" href="/">For jobsøgere</a>
# </li> <li>
# <a class="audience-link" href="/virksomheder">For arbejdsgivere</a>
# </li> <li class="language-selector">
# <a class="active" data-click-action="click-switch-lang" href="/jobsoegning/storkoebenhavn?page=3&amp;q=python&amp;geoareaid=15182&amp;lang=da">DA</a>
# <a data-click-action="click-switch-lang" href="/jobsoegning/storkoebenhavn?page=3&amp;q=python&amp;geoareaid=15182&amp;lang=en">EN</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="col-3 col-sm-2 d-lg-none text-right">
# <nav class="main-navigation login-navigation">
# <ul>
# <li><a class="main-nav-link" data-jix-login="user" href="/bruger/log-ind">Log ind</a></li>
# <li class="d-none d-lg-inline"><a class="main-nav-link" href="/bruger/opret">Tilmeld dig</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# </header>
# <nav class="site-header">
# <div class="container-navigation">
# <div class="container container-navigation-mobile">
# <div class="row">
# <div class="col-md-9">
# <nav class="main-navigation" id="main-navigation">
# <ul>
# <li>
# <a aria-controls="megamenu-entry-jobseeker-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-jobseeker-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Din jobsøgning</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-jobseeker-label" class="megamenu" id="megamenu-entry-jobseeker-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Din side" href="/din-side">
#                                     Din side
#                                     <small class="form-text text-muted">Skab overblik over din jobsøgning</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobagenter" href="/jobagent">
#                                     Jobagenter
#                                     <small class="form-text text-muted">Få nye job direkte i din indbakke</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="CV" href="/cv">
#                                     CV
#                                     <small class="form-text text-muted">Opret dit CV og bliv headhuntet</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="QuickApply-profil" href="/quickapply">
#                                     QuickApply-profil
#                                     <small class="form-text text-muted">Søg jobbet nemt fra mobilen</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Inspiration til din jobsøgning - alt fra CV og ansøgning til jobsamtale og lønforhandling" href="/inspiration">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/inspiration-til-jobsoegning.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration-til-jobsoegning.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration-til-jobsoegning.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration-til-jobsoegning.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Inspiration til din jobsøgning - alt fra CV og ansøgning til jobsamtale og lønforhandling</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# <li class="selected">
# <a aria-controls="megamenu-entry-jobads-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-jobads-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Jobannoncer</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-jobads-label" class="megamenu" id="megamenu-entry-jobads-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li class="selected">
# <a data-click-action="click-megamenu" data-click-label="Avanceret søgning" href="/?adv=1">
#                                     Avanceret søgning
#                                     <small class="form-text text-muted">Vælg mellem flere søgekriterier</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobannoncearkiv" href="/jobsoegning?archive=1">
#                                     Jobannoncearkiv
#                                     <small class="form-text text-muted">Find inspiration i udløbne jobopslag</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Opret en Jobagent og lad jobbet komme til dig" href="/jobagent">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/jobads.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/jobads.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/jobads.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/jobads.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Opret en Jobagent og lad jobbet komme til dig</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# <li>
# <a aria-controls="megamenu-entry-companyprofiles-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-companyprofiles-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Virksomhedsprofiler</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-companyprofiles-label" class="megamenu" id="megamenu-entry-companyprofiles-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Se virksomhedsprofiler" href="/virksomhedsoversigt">
#                                     Se virksomhedsprofiler
#                                     <small class="form-text text-muted">Få viden om din næste arbejdsplads</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Evaluér arbejdsplads" href="/cms/evaluer-din-arbejdsplads">
#                                     Evaluér arbejdsplads
#                                     <small class="form-text text-muted">Hvordan er din arbejdsplads?</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Elevplads" href="/elevplads">
#                                     Elevplads
#                                     <small class="form-text text-muted">Se virksomheder med elevpladser</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Graduate program" href="/graduate-program">
#                                     Graduate program
#                                     <small class="form-text text-muted">Se virksomheder med Graduate Programmer</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Hvilken arbejdsplads passer du ind hos? Tag persontypetesten" href="/persontypetest">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/companyprofiles.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/companyprofiles.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/companyprofiles.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/companyprofiles.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Hvilken arbejdsplads passer du ind hos? Tag persontypetesten</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# <li>
# <a aria-controls="megamenu-entry-testcenter-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-testcenter-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Test dig selv</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-testcenter-label" class="megamenu" id="megamenu-entry-testcenter-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Tjek din løn" href="/tjek-din-loen">
#                                     Tjek din løn
#                                     <small class="form-text text-muted">Hvad tjener andre som dig?</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobglædetest" href="/test-dig-selv/jobglaede">
#                                     Jobglædetest
#                                     <small class="form-text text-muted">Hvordan er din jobglæde?</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Persontypetest" href="/persontypetest">
#                                     Persontypetest
#                                     <small class="form-text text-muted">Kender du dine styrker?</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Stresstest" href="/stress">
#                                     Stresstest
#                                     <small class="form-text text-muted">Mål dit stressniveau</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Talenttest" href="/talenttest">
#                                     Talenttest
#                                     <small class="form-text text-muted">Find dine arbejdstalenter</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Få personlig rådgivning og hjælp til din jobsøgning" href="/cms/jobvejledning">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/testcenter.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/testcenter.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/testcenter.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/testcenter.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Få personlig rådgivning og hjælp til din jobsøgning</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# <li>
# <a aria-controls="megamenu-entry-inspiration-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-inspiration-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Inspiration</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-inspiration-label" class="megamenu" id="megamenu-entry-inspiration-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobglæde" href="/jobglaede">
#                                     Jobglæde
#                                     <small class="form-text text-muted">Sæt jobglæde på agendaen</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Ansøgning" href="/inspiration/ansoegningen">
#                                     Ansøgning
#                                     <small class="form-text text-muted">Inspiration til din ansøgning</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="CV-skabelon" href="/inspiration/optimer-dit-cv">
#                                     CV-skabelon
#                                     <small class="form-text text-muted">Få gode råd til dit CV</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobsamtale" href="/inspiration/jobsamtalen">
#                                     Jobsamtale
#                                     <small class="form-text text-muted">Forbered dig til jobsamtalen</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Løn" href="/inspiration/loen-og-loenforhandling">
#                                     Løn
#                                     <small class="form-text text-muted">Bliv klar til din lønforhandling</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Dit første job" href="/dit-foerste-job">
#                                     Dit første job
#                                     <small class="form-text text-muted">Værktøjer og tips til dit nye arbejdsliv</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Tjek din løn og se lønniveauet for profiler som din" href="/tjek-din-loen">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/inspiration.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/inspiration.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Tjek din løn og se lønniveauet for profiler som din</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# <li>
# <a aria-controls="megamenu-entry-guidance-content" aria-expanded="false" class="main-nav-link" href="/" id="megamenu-entry-guidance-label" role="button"><svg class="svg-icon svg-icon-inline main-menu-marker"><use xlink:href="#svg-list-marker" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>Vejledning</a>
# <div aria-expanded="false" aria-hidden="true" aria-labelledby="megamenu-entry-guidance-label" class="megamenu" id="megamenu-entry-guidance-content" role="region">
# <div class="site-nav-group">
# <div class="row">
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Få en jobvejleder" href="/cms/jobvejledning">
#                                     Få en jobvejleder
#                                     <small class="form-text text-muted">Bliv afklaret i din jobsøgning</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Ansøgningsmaskinen" href="/ansoegningsmaskinen">
#                                     Ansøgningsmaskinen
#                                     <small class="form-text text-muted">Hjælp til at skrive en jobansøgning</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobindex TV" href="https://jobindex.tv/" rel="noopener" target="_blank">
#                                     Jobindex TV
#                                     <small class="form-text text-muted">Videotips til jobsøgere</small>
# </a></li> </ul>
# <ul>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Kurser for ledige" href="https://jobindexkurser.dk/" rel="noopener" target="_blank">
#                                     Kurser for ledige
#                                     <small class="form-text text-muted">Opgrader dine kompetencer</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Jobsøgningskursus" href="/annaway">
#                                     Jobsøgningskursus
#                                     <small class="form-text text-muted">Skab struktur i din jobsøgning</small>
# </a></li>
# <li>
# <a data-click-action="click-megamenu" data-click-label="Kaares Klumme" href="/blogs/job">
#                                     Kaares Klumme
#                                     <small class="form-text text-muted">Vinkler på din jobsøgning</small>
# </a></li> </ul>
# <div class="megamenu-card-wrapper d-none d-lg-flex">
# <div class="article-card">
# <a data-click-action="click-card" data-click-label="Hvordan skriver du et godt CV?" href="/cms/cv-skabelon">
# <div class="card-image"><img alt="" loading="lazy" src="/img/jobindex20/megamenu/cards/jobseeker/guidance.jpg" srcset="/api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/guidance.jpg?max_height=231 1x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/guidance.jpg?max_height=347 1.5x, /api/imagescaler/v1/jobindex20/megamenu/cards/jobseeker/guidance.jpg?max_height=462 2x"/></div>
# <div class="card-body">
# <h3 class="card-title">Hvordan skriver du et godt CV?</h3>
# <svg class="svg-icon svg-icon-sm"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </div>
# </a></div>
# </div>
# </div>
# </div>
# </div></li>
# </ul>
# <ul class="main-nav-mobile d-lg-none">
# <li>
# <a href="/virksomheder">For arbejdsgivere <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-linkarrow-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg></a>
# </li>
# <li class="signup">
# <a href="/bruger/opret">Tilmeld dig Jobindex</a>
# </li>
# <li class="language-selector">
# <a data-click-action="click-switch-lang" href="/jobsoegning/storkoebenhavn?page=3&amp;q=python&amp;geoareaid=15182&amp;lang=en">Switch to English</a>
# </li>
# </ul>
# </nav>
# </div>
# <div class="col-md-3 d-none d-lg-block">
# <nav class="main-navigation login-navigation">
# <ul>
# <li><a class="main-nav-link" data-jix-login="user" href="/bruger/log-ind">Log ind</a></li>
# <li class="d-none d-lg-inline"><a class="main-nav-link" href="/bruger/opret">Tilmeld dig</a></li>
# </ul>
# </nav>
# </div>
# </div>
# </div>
# </div>
# <div class="container position-relative">
# <div aria-hidden="true" class="profile-container" id="profile-menu-content" role="region">
# </div>
# </div>
# <div class="megamenu-curtain d-none d-lg-flex"></div>
# <div class="mobile-background d-lg"></div>
# </nav>
# <nav class="nav-bottom">
# <ul class="nav-bottom__list">
# <li class="nav-bottom__item">
# <a class="nav-bottom__link nav-bottom__link--active" data-click-label="Søg job" href="/?adv=1">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-jobsearch" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="nav-bottom__label">Søg job</span>
# </a>
# </li>
# <li class="nav-bottom__item">
# <a class="nav-bottom__link" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/bruger/dine-job" href="/bruger/dine-job">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-myjob-unsaved" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="nav-bottom__label">Gemte job</span>
# </a>
# </li>
# <li class="nav-bottom__item">
# <a class="nav-bottom__link" data-click-label="Jobagenter" href="/jobagent">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-jobagent" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="nav-bottom__label">Jobagenter</span>
# </a>
# </li>
# <li class="nav-bottom__item dropup">
# <a aria-expanded="false" aria-haspopup="true" class="nav-bottom__link" data-click-label="Mere" data-toggle="dropdown" href="#" id="nav-bottom__more" role="button">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-options-menu" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# <span class="nav-bottom__label">Mere</span>
# </a> <div aria-labelledby="nav-bottom__more" class="dropdown-menu">
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/din-side" href="/din-side">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-mypage" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Overblik
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/bruger/ansoegninger" href="/bruger/ansoegninger">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-applications" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Ansøgninger
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/bruger/henvendelser" href="/bruger/henvendelser">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-contacts" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Henvendelser
# </a>
# <a class="dropdown-item" href="/cv">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-cv" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     CV
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/quickapply" href="/quickapply">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-quickapply" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     QuickApply-profil
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/bruger/dine-virksomheder" href="/bruger/dine-virksomheder">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-mycompany" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Virksomheder
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/vejledning" href="/vejledning">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-service-user-guidance" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Råd og vejledning
# </a>
# <a class="dropdown-item" data-click-label="Gemte job" data-jix-login="user" data-jix-login-redirect="/bruger" href="/bruger">
# <svg class="svg-icon svg-icon-sm nav-bottom__icon"><use xlink:href="#svg-settings" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
#                     Indstillinger
# </a> </div>
# </li>
# </ul>
# </nav>
# <main>
# <section class="mb-5" id="lock_while_searching">
# <a href="https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&amp;q=python" id="ajax_canonical_link" style="display: none;"></a>
# <div class="container mb-3 mb-md-5 mt-4">
# <h1 class="jobsearch-header h2 mb-4 mb-md-4 color-current">
# <span class="d-none d-md-inline">127 job matcher din søgning</span>
# <span class="d-md-none">127 job fundet</span>
# </h1>
# <div class="d-print-none">
# <!-- Search component -->
# <div class="search-component" id="search-component">
# <form action="/jobsoegning" class="form-horizontal" id="jobsearch" method="get" role="form">
# <div class="row">
# <div class="col-lg-5 col-12 mb-3">
# <input aria-label="Søg efter job" class="form-control" name="q" placeholder="Søg efter job" type="text" value="python"/>
# </div>
# <div class="col-lg-4 col-12 mb-3">
# <select aria-label="Vælg eller indtast områder" class="form-control" id="geoareas" multiple="multiple" name="geoareaid" placeholder="Vælg eller indtast områder" title="Område"></select>
# <script>//<![CDATA[
# jQuery("#geoareas").jix_geoarea({"containerCssClass":"form-control ","context":"job","data":[{"code":"storkbh","count":null,"id":15182,"text":"Storkøbenhavn","text_hl":"Storkøbenhavn","type":"Område","typeid":0},{"code":"nordsj","count":null,"id":15187,"text":"Nordsjælland","text_hl":"Nordsjælland","type":"Område","typeid":0},{"code":"1085","count":null,"id":4,"text":"Region Sjælland","text_hl":"Region Sjælland","type":"Region","typeid":20},{"code":"fyn","count":null,"id":15179,"text":"Fyn","text_hl":"Fyn","type":"Område","typeid":0},{"code":"1081","count":null,"id":3,"text":"Region Nordjylland","text_hl":"Region Nordjylland","type":"Region","typeid":20},{"code":"1082","count":null,"id":2,"text":"Region Midtjylland","text_hl":"Region Midtjylland","type":"Region","typeid":20},{"code":"sydjylland","count":null,"id":15180,"text":"Sydjylland","text_hl":"Sydjylland","type":"Område","typeid":0},{"code":"0400","count":null,"id":15,"text":"Bornholm","text_hl":"Bornholm","type":"Kommune","typeid":30},{"code":"skaane","count":null,"id":16149,"text":"Skåne","text_hl":"Skåne","type":"Område","typeid":0},{"code":"GL","count":null,"id":15271,"text":"Grønland","text_hl":"Grønland","type":"Land","typeid":10},{"code":"FO","count":null,"id":15799,"text":"Færøerne","text_hl":"Færøerne","type":"Land","typeid":10},{"code":"foreign","count":null,"id":15185,"text":"Udlandet","text_hl":"Udlandet","type":"Område","typeid":0},{"code":"DK","count":null,"id":1221,"text":"Danmark","text_hl":"Danmark","type":"Land","typeid":10}],"default_list":[{"code":"storkbh","count":null,"id":15182,"text":"Storkøbenhavn","text_hl":"Storkøbenhavn","type":"Område","typeid":0},{"code":"nordsj","count":null,"id":15187,"text":"Nordsjælland","text_hl":"Nordsjælland","type":"Område","typeid":0},{"code":"1085","count":null,"id":4,"text":"Region Sjælland","text_hl":"Region Sjælland","type":"Region","typeid":20},{"code":"fyn","count":null,"id":15179,"text":"Fyn","text_hl":"Fyn","type":"Område","typeid":0},{"code":"1081","count":null,"id":3,"text":"Region Nordjylland","text_hl":"Region Nordjylland","type":"Region","typeid":20},{"code":"1082","count":null,"id":2,"text":"Region Midtjylland","text_hl":"Region Midtjylland","type":"Region","typeid":20},{"code":"sydjylland","count":null,"id":15180,"text":"Sydjylland","text_hl":"Sydjylland","type":"Område","typeid":0},{"code":"0400","count":null,"id":15,"text":"Bornholm","text_hl":"Bornholm","type":"Kommune","typeid":30},{"code":"skaane","count":null,"id":16149,"text":"Skåne","text_hl":"Skåne","type":"Område","typeid":0},{"code":"GL","count":null,"id":15271,"text":"Grønland","text_hl":"Grønland","type":"Land","typeid":10},{"code":"FO","count":null,"id":15799,"text":"Færøerne","text_hl":"Færøerne","type":"Land","typeid":10},{"code":"foreign","count":null,"id":15185,"text":"Udlandet","text_hl":"Udlandet","type":"Område","typeid":0},{"code":"DK","count":null,"id":1221,"text":"Danmark","text_hl":"Danmark","type":"Land","typeid":10}],"multiple":true,"no_country":1,"radius":true}).val([15182]).trigger("change");
#
# //]]></script>
# </div>
# <div class="col-lg-3 d-none d-lg-block">
# <button class="btn btn-primary btn-block" type="submit">Søg</button>
# </div>
# </div>
# <div class="row d-none geo-radius-row">
# <div class="col-12">
# <label class="control-label" for="radius_field">Radius:</label>
# </div>
# <div class="col-md-5 geo-radius-col geo-radius-col-slider mb-3">
# <div class="jix-range">
# <input disabled="" id="radius_slider" max="100" min="1" name="radius" step="1" style="--jix-slider-pct:48.989898989899%" type="range" value=""/>
# </div>
# </div> <div class="col-md-7 geo-radius-col geo-radius-col-input mb-3">
# <input class="form-control" disabled="" id="radius_field" max="100" min="1" name="radius" required="" step="1" type="number" value="50"/>
# <span><abbr title="kilometer">km</abbr> fra</span>
# <div class="dawa-autocomplete-container">
# <div class="input-group">
# <input class="form-control" data-always-enabled="true" id="radius_address" name="address" placeholder="Indtast adresse" value=""/>
# <div class="input-group-append">
# <button class="btn btn-secondary address-input__geolocation" title="Brug min placering" type="button">
# <svg class="svg-icon svg-icon-inline"><use xlink:href="#svg-geolocation" xmlns:xlink="http://www.w3.org/1999/xlink"></use></svg>
# </button> </div>
# </div>
# </div>
# </div></div>
# <div class="mb-4 mb-md-0">
# <div class="row">
# <div class="col text-right">
# <a aria-controls="jobsearch-advanced" aria-expanded="false" class="text-muted link-basic collapsed" data-toggle="collapse" href="#jobsearch-advanced" id="jobsearch-advanced-toggle">
# <span class="toggle-text-hidden">Flere søgemuligheder +</span>
# <span class="toggle-text-shown">Færre søgemuligheder -</span>
# </a>
# </div>
# </div>
# <div aria-expanded="false" class="row collapse" id="jobsearch-advanced">
# <div class="col-lg-5 mb-3">
# <label class="control-label" for="category">Jobkategori</label>
# <select class="form-control" id="category" multiple="" name="subid" placeholder="Vælg kategorier" title="Jobkategori"><optgroup label="Informationsteknologi"><option value="93">Database</option><option value="6">Internet og WWW</option><option value="4">IT-drift og support</option><option value="116">IT-kurser for ledige</option><option value="3">IT-ledelse</option><option value="1">Systemudvikling og programmering</option><option value="7">Tele- og datakommunikation</option><option value="2">Økonomi- og virksomhedssystemer</option></optgroup><optgroup label="Ingeniør og teknik"><option value="8">Bygge- og anlægsteknik</option><option value="11">Elektroteknik</option><option value="94">Kemi og bioteknik</option><option value="121">Ledelse inden for ingeniør og teknik</option><option value="85">Maskinteknik</option><option value="10">Medicinal og levnedsmiddel</option><option value="122">Produktions- og procesteknik</option></optgroup><optgroup label="Ledelse og personale"><option value="124">Detailledelse</option><option value="26">Freelancekonsulent</option><option value="118">HR- og ledelseskurser for ledige</option><option value="79">Institutions- og skoleledelse</option><option value="3">IT-ledelse</option><option value="14">Ledelse</option><option value="121">Ledelse inden for ingeniør og teknik</option><option value="12">Personale og HR</option><option value="61">Projektledelse</option><option value="75">Salgsledelse</option><option value="13">Topledelse og bestyrelse</option><option value="125">Virksomhedsudvikling</option><option value="81">Økonomiledelse</option></optgroup><optgroup label="Handel og service"><option value="99">Bud og udbringning</option><option value="23">Børnepasning</option><option value="70">Detailhandel</option><option value="124">Detailledelse</option><option value="98">Ejendomsservice</option><option value="56">Frisør og personlig pleje</option><option value="67">Hotel, restaurant og køkken</option><option value="73">Rengøring</option><option value="71">Service</option><option value="112">Sikkerhed</option></optgroup><optgroup label="Industri og håndværk"><option value="96">Blik og rør</option><option value="24">Bygge og anlæg</option><option value="80">Elektriker</option><option value="44">Industriel produktion</option><option value="90">Jern og metal</option><option value="74">Lager</option><option value="25">Landbrug, skov og fiskeri</option><option value="97">Maling og overfladebehandling</option><option value="95">Mekanik og auto</option><option value="36">Nærings- og nydelsesmiddel</option><option value="92">Tekstil og kunsthåndværk</option><option value="83">Transport</option><option value="104">Træ- og møbelindustri</option><option value="40">Tømrer og snedker</option></optgroup><optgroup label="Salg og kommunikation"><option value="110">Design og formgivning</option><option value="60">Ejendomsmægler</option><option value="89">Grafisk</option><option value="49">Kommunikation og journalistik</option><option value="65">Kultur og kirke</option><option value="55">Marketing</option><option value="58">Salg</option><option value="75">Salgsledelse</option><option value="117">Salgs- og kommunikationskurser for ledige</option><option value="120">Selvstændig virksomhedsdrift</option><option value="57">Telemarketing</option></optgroup><optgroup label="Undervisning"><option value="37">Bibliotek</option><option value="45">Forskning</option><option value="79">Institutions- og skoleledelse</option><option value="28">Lærer</option><option value="27">Pædagog</option><option value="103">Voksenuddannelse</option></optgroup><optgroup label="Kontor og økonomi"><option value="126">Akademisk og politisk arbejde</option><option value="60">Ejendomsmægler</option><option value="98">Ejendomsservice</option><option value="35">Finans og forsikring</option><option value="53">Indkøb</option><option value="52">Jura</option><option value="18">Kontor</option><option value="22">Kontorelev</option><option value="119">Kontor ...
# </div>
# <div class="col-lg-4 mb-3">
# <label class="control-label" for="companies">Virksomhed</label>
# <select class="form-control" id="companies" multiple="" name="companyid" placeholder="Virksomhedsnavn" title="Virksomhed"></select>
# </div>
# <div class="col-lg-3 mb-3">
# <label class="control-label" for="jobage">Opslagsdato</label>
# ...
# <symbol id="svg-myjob-saved" viewbox="0 0 24 24"><path d="M23.3 5.076a6.582 6.582 0 00-10.446-1.71L12 4.147l-.827-.753a6.522 6.522 0 00-5.688-1.806A6.472 6.472 0 00.7 5.075a6.4 6.4 0 001.21 7.469l9.373 9.656a1 1 0 001.434 0l9.36-9.638A6.414 6.414 0 0023.3 5.076z" stroke="none"></path></symbol>
# <symbol id="svg-myjob-unsaved" viewbox="0 0 24 24"><path d="M12 21.932L2.2 11.84a5.667 5.667 0 01-1.087-6.607h0A5.839 5.839 0 0110.4 3.746L12 5.205l1.6-1.459a5.84 5.84 0 019.287 1.487h0A5.669 5.669 0 0121.8 11.84z" fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"></path></symbol>
# <symbol id="svg-options-menu" viewbox="0 0 140 140"><path d="M52.5 122.5a17.5 17.5 0 1035 0 17.5 17.5 0 10-35 0zM52.5 70a17.5 17.5 0 1035 0 17.5 17.5 0 10-35 0zM52.5 17.5a17.5 17.5 0 1035 0 17.5 17.5 0 10-35 0z" fill="currentColor" stroke="none"></path></symbol>
# <symbol id="svg-pagination-arrow"><use xlink:href="#svg-collapse-right" xmlns:xlink="http://www.w3.org/1999/xlink"></use></symbol>
# <symbol id="svg-rating-selected" viewbox="0 0 18 17"><path d="M9 13.5l-5.29 2.781 1.01-5.89L.44 6.219l5.915-.86L9 0l2.645 5.36 5.915.859-4.28 4.172 1.01 5.89z" fill-rule="evenodd"></path></symbol>
# <symbol id="svg-rating-unselected" viewbox="0 0 18 17"><path d="M13.626 15.367l-.883-5.151 3.742-3.648-5.172-.752L9 1.13 6.687 5.816l-5.172.752 3.742 3.648-.883 5.151L9 12.935l4.626 2.432z" fill="none" stroke="currentColor" stroke-width="1.5"></path></symbol>
# <symbol id="svg-service-applications" viewbox="0 0 60 60"><g fill="none" stroke-linecap="round" stroke-linejoin="round"><path d="M27.5 46.25H3.75a2.5 2.5 0 0 1-2.5-2.5v-40a2.5 2.5 0 0 1 2.5-2.5h37.5a2.5 2.5 0 0 1 2.5 2.5v25M39.25 55.75l-10.5 3 3-10.5 17.948-17.948a5.303 5.303 0 0 1 7.5 7.5zM47.447 32.553l7.5 7.5M31.75 48.25l7.5 7.5M15 11.25h17.5M10 18.75h22.5M10 26.25h22.5M10 33.75h16.25" stroke-width="2.5"></path></g></symbol>
# <symbol id="svg-service-contacts" viewbox="0 0 60 60"><g fill="none" stroke-linecap="round" stroke-linejoin="round"><path d="M58.75 42.5a2.5 2.5 0 0 1-2.5 2.5h-27.5l-10 10V45h-15a2.5 2.5 0 0 1-2.5-2.5v-35A2.5 2.5 0 0 1 3.75 5h52.5a2.5 2.5 0 0 1 2.5 2.5zM13.75 30h32.5M13.75 17.5h32.5" stroke-width="2.5"></path></g></symbol>
# <symbol id="svg-service-cv" viewbox="0 0 60 60"><g fill="none" stroke-linecap="round" stroke-linejoin="round"><path d="m28.75 58.75-6.633-7.698a3.753 3.753 0 0 1 5.768-4.802l5.865 7.065V28.75a3.75 3.75 0 0 1 7.5 0v15h7.5a10 10 0 0 1 10 10v5M33.75 20V8.75a2.5 2.5 0 0 0-2.5-2.5H3.75a2.5 2.5 0 0 0-2.5 2.5v42.5a2.5 2.5 0 0 0 2.5 2.5H15" stroke-width="2.5"></path><path d="M38.75 20V3.75a2.5 2.5 0 0 0-2.5-2.5H7.5M8.75 38.75h17.5M13.125 18.125a4.375 4.375 0 1 0 8.75 0 4.375 4.375 0 1 0-8.75 0zM26.25 31.25a9.03 9.03 0 0 0-17.5 0z" stroke-width="2.5"></path></g></symbol>
# <symbol id="svg-service-jobagent" viewbox="0 0 40 40"><g fill="none" fill-rule="evenodd" stroke-linecap="round" stroke-linejoin="round" stroke-width="1.5"><path d="M28.75 18.75c5.523 0 10 4.477 10 10s-4.477 10-10 10-10-4.477-10-10 4.477-10 10-10zM28.75 23.75v10M23.75 28.75h10"></path><path d="M13.75 26.25h-10a2.5 2.5 0 01-2.5-2.5v-20a2.5 2.5 0 012.5-2.5h30a2.5 2.5 0 012.5 2.5V15"></path><path d="M35.685 2.167l-13.573 10.44a5.512 5.512 0 01-6.724 0L1.815 2.167"></path></g></symbol>
# <symbol id="svg-service-jobsearch" viewbox="0 0 24 24"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><circle cx="8.5" cy="8.5" r="8"></circle><line x1="14.156" x2="23.5" y1="14.156" y2="23.5"></line></g></symbol>
# <symbol id="svg-service-mycompany" viewbox="0 0 60 60"><g fill="none" stroke-linecap="round" stroke-linejoin="round"><path d="M38.75 2.555A1.25 1.25 0 0 1 40 1.305h17.483a1.25 1.25 0 0 1 1.25 1.25V57.5a1.25 1.25 0 0 1-1.25 1.25H38.75zM38.74 58.75H18.762V31.277H38.74M29.635 22.17a1.25 1.25 0 0 0-1.768 0l-9.104 9.107H38.75zM18.762 58.75H5.025a1.25 1.25 0 0 1-1.25-1.25V46.25h14.987" stroke-width="2.5"></path><path d="M18.762 38.77H6.942a1.25 1.25 0 0 0-1.04.555l-3.33 5a1.25 1.25 0 0 0 1.04 1.942h15.15M43.735 6.303V8.8M48.73 6.303V8.8M53.725 6.303V8.8M43.735 16.293v2.497M48.73 16.293v2.497M53.725 16.293v2.497M43.735 26.282v2.498M48.73 26.282v2.498M53.725 26.282v2.498M43.735 36.273v2.497M48.73 36.273v2.497M53.725 36.273v2.497M23.912 39.962v2.498M28.908 39.962v2.498M33.903 39.962v2.498M23.912 49.953v2.497M28.908 49.953v2.497M33.903 49.953v2.497M43.735 46.262v2.498M48.73 46.262v2.498M53.725 46.262v2.498M21.418 16.293a5.513 5.513 0 0 0 4.832-5.375 5.365 5.365 0 0 0-5.565-5.36 7.5 7.5 0 0 0-6.787-4.308 7.75 7.75 0 0 0-7.75 7.068 4.03 4.03 0 0 0-4.868 3.945 4.082 4.082 0 0 0 4.298 4.03z" stroke-width="2.5"></path></g></symbol>
# <symbol id="svg-service-mypage" viewbox="0 0 24 24"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><rect height="7" rx="1" ry="1" width="10" x="0.5" y="16.5"></rect><rect height="13" rx="1" ry="1" transform="translate(37 34) rotate(180)" width="10" x="13.5" y="10.5"></rect><rect height="7" rx="1" ry="1" transform="translate(37 8) rotate(180)" width="10" x="13.5" y="0.5"></rect><rect height="13" rx="1" ry="1" width="10" x="0.5" y="0.5"></rect></g></symbol>
# <symbol id="svg-service-quickapply" viewbox="0 0 24 24"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><line x1="18.501" x2="15.501" y1="7.497" y2="7.497"></line><line x1="16.501" x2="14.501" y1="2.497" y2="4.497"></line><line x1="11.501" x2="11.501" y1="0.498" y2="3.497"></line><line x1="5.501" x2="7.501" y1="2.497" y2="4.497"></line><line x1="3.501" x2="6.501" y1="7.497" y2="7.497"></line><path d="M8.654,23.5,4.847,18.919A1.5,1.5,0,0,1,7.154,17L9.5,19.825V10a1.5,1.5,0,1,1,3,0v6.5h3a4,4,0,0,1,4,4v3"></path></g></symbol>
# <symbol id="svg-service-user-guidance" viewbox="0 0 24 24"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M17,18a1.5,1.5,0,0,1-1.5-1.5v-5A1.5,1.5,0,0,1,17,10a3,3,0,1,0-3-3,1.5,1.5,0,0,1-3,0,6,6,0,1,1,7.5,5.811V16.5A1.5,1.5,0,0,1,17,18Z"></path><circle cx="17" cy="21.5" r="1.5"></circle><path d="M7,6A1.5,1.5,0,0,1,8.5,7.5v5A1.5,1.5,0,0,1,7,14a3,3,0,1,0,3,3,1.5,1.5,0,0,1,3,0,6,6,0,1,1-7.5-5.811V7.5A1.5,1.5,0,0,1,7,6Z"></path><circle cx="7" cy="2.5" r="1.5"></circle></g></symbol>
# <symbol id="svg-settings" viewbox="0 0 24 24"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M20.254,13.5H22.5a1,1,0,0,0,1-1v-1a1,1,0,0,0-1-1H20.253a11.8,11.8,0,0,0-1-2.922l1.589-1.588a1,1,0,0,0,0-1.414L19.424,3.162a1,1,0,0,0-1.414,0L16.42,4.751a11.769,11.769,0,0,0-2.92-1V1.5a1,1,0,0,0-1-1h-1a1,1,0,0,0-1,1V3.749a11.777,11.777,0,0,0-2.921,1L5.989,3.162a1,1,0,0,0-1.414,0L3.16,4.577a1,1,0,0,0,0,1.414L4.75,7.58a11.821,11.821,0,0,0-1,2.921H1.5a1,1,0,0,0-1,1v1a1,1,0,0,0,1,1H3.746a11.821,11.821,0,0,0,1,2.921l-1.59,1.59a1,1,0,0,0,0,1.414L4.575,20.84a1,1,0,0,0,1.414,0L7.578,19.25a11.8,11.8,0,0,0,2.922,1V22.5a1,1,0,0,0,1,1h1a1,1,0,0,0,1-1V20.255a11.8,11.8,0,0,0,2.92-1l1.591,1.589a1,1,0,0,0,1.414,0l1.414-1.414a1,1,0,0,0,0-1.414l-1.589-1.59A11.821,11.821,0,0,0,20.254,13.5Z"></path><circle cx="12" cy="12.001" r="4.5"></circle></g></symbol>
# <symbol id="svg-share-email" viewbox="0 0 30 30"><g stroke="none"><path d="M18.5 14.5l-3.6 3.2-3.5-3.2L6.8 20h16.4l-4.7-5.5M6 9.7v9.7l4.6-5.6L6 9.7m18 0l-4.7 4.1 4.7 5.6V9.7m-.8-.7H6.7l5.3 4.7 2.9 2.6L23.2 9M5 8.5V8h20v13H5V8.5M15 0a15 15 0 1015 15A15 15 0 0015 0"></path></g></symbol>
# <symbol id="svg-share-facebook" viewbox="0 0 40 40"><path d="M17.2 30.9h4.5V20h3l.4-3.8h-3.4v-1.8c0-1 .1-1.5 1.5-1.5H25V9.1h-3c-3.6 0-4.8 1.8-4.8 4.9v2.2h-2.3V20h2.3v10.9zM20 40C9 40 0 31 0 20S9 0 20 0s20 9 20 20-9 20-20 20z" stroke-width="0"></path></symbol>
# <symbol id="svg-share-instagram" viewbox="0 0 40 40"><path d="M26.2 15.1V15c.3 0 .7.1 1 0 .4 0 .8-.3.8-.8v-1.9c0-.5-.4-.8-.9-.8h-1.9c-.4 0-.8.3-.8.8V14.5c.2.3.5.6.9.6h.9zm-6.2.8c-2.3 0-4.1 1.8-4.1 4-.1 2.3 1.8 4.2 4 4.2 2.3.1 4.2-1.8 4.2-4 .1-2.3-1.8-4.2-4.1-4.2zm-8 2.2v9.1c0 .4.4.8.8.8h14.4c.4 0 .8-.4.8-.8v-9.1h-2c.3.9.4 1.7.3 2.7-.1.9-.4 1.7-.9 2.5s-1.1 1.4-1.9 1.9c-1.9 1.4-4.5 1.5-6.6.3-1-.6-1.9-1.4-2.4-2.5-.9-1.5-1-3.2-.5-4.9h-2zm16.1 12.1c.1 0 .2-.1.4-.1.8-.2 1.5-.9 1.6-1.7 0-.1.1-.2.1-.3V11.9c0-.1-.1-.2-.1-.3-.2-.9-.9-1.6-1.8-1.7l-.1-.1H11.8c-.1 0-.2.1-.3.1-.9.2-1.5.9-1.6 1.8l-.1.1v16.4c0 .1.1.2.1.3.2.9.9 1.5 1.8 1.7h16.4zM20 40C9 40 0 31 0 20S9 0 20 0s20 9 20 20-9 20-20 20z" stroke-width="0"></path></symbol>
# <symbol id="svg-share-link" viewbox="0 0 30 30"><g stroke="none"><path d="M15 0a15 15 0 1015 15A15 15 0 0015 0zm.7 19.9l-3.2 3.2a3.9 3.9 0 01-2.4 1 3.9 3.9 0 01-2.5-1l-.7-.7a3.6 3.6 0 010-5l4.6-4.5a3.4 3.4 0 014.9 0l.7.7a.5.5 0 01-.7.7l-.7-.7a2.4 2.4 0 00-3.5 0l-4.6 4.6a2.1 2.1 0 00-.7 1.7 2.1 2.1 0 00.7 1.7l.7.8a2.6 2.6 0 003.5 0l3.2-3.2a.5.5 0 11.7.7zm7.4-7.3l-4.6 4.5a3.4 3.4 0 01-4.9 0l-.7-.7a.5.5 0 11.7-.7l.7.7a2.4 2.4 0 003.5 0l4.6-4.6a2.1 2.1 0 00.7-1.7 2.1 2.1 0 00-.7-1.7l-.7-.8a2.6 2.6 0 00-3.5 0L15 10.8a.5.5 0 01-.7-.7l3.2-3.2a3.9 3.9 0 012.4-1 3.9 3.9 0 012.5 1l.7.7a3.5 3.5 0 011 2.5 3.5 3.5 0 01-1 2.5z"></path></g></symbol>
# <symbol id="svg-share-linkedin" viewbox="0 0 40 40"><path d="M31.2 29.4v-7.8c0-4.2-2.2-6.1-5.2-6.1-2.4 0-3.5 1.3-4.1 2.2v-1.9h-4.5c.1 1.3 0 13.6 0 13.6h4.5v-7.6c0-.4.1-.8.2-1.1.3-.8 1.1-1.6 2.3-1.6 1.6 0 2.3 1.2 2.3 3v7.3h4.5zM12.6 13.9c1.6 0 2.6-1 2.6-2.3 0-1.3-1-2.4-2.5-2.4-1.6 0-2.6 1.1-2.6 2.4 0 1.3 1 2.3 2.5 2.3zM20 40C9 40 0 31 0 20S9 0 20 0s20 9 20 20-9 20-20 20zm-5.1-10.6V15.8h-4.5v13.6h4.5z" stroke-width="0"></path></symbol>
# <symbol id="svg-share-native" viewbox="0 0 30 30"><g stroke="none"><path d="M25.56 4.4C22.772 1.6 18.986 0 15 0 6.73 0 .056 6.7.056 15S6.73 30 15 30c8.27 0 14.944-6.7 14.944-15 0-4-1.594-7.8-4.383-10.6zM11.813 9c.133-.133 1.063-1.133 2.79-3l.1-.1c.066-.066.132-.1.198-.1.067 0 .133.034.2.1l.1.1a351.118 351.118 0 002.789 3c.2.2.215.484 0 .7-.216.216-.482.216-.698 0-.143-.144-.774-.844-1.892-2.1V15c0 .3-.2.5-.499.5s-.498-.2-.498-.5V7.6L12.51 9.7c-.199.2-.498.2-.697 0-.2-.2-.2-.5 0-.7zm7.572 13.2h-8.768c-.597 0-1.096-.6-1.096-1.2v-8.7c0-.6.49-1.2 1.096-1.2h2.491c.299 0 .498.2.498.5s-.2.5-.498.5h-2.49c-.1 0-.1.1-.1.2V21c0 .2.1.2.1.2h8.667c.1 0 .1-.1.1-.2v-8.7c0-.2-.1-.2-.1-.2h-2.49c-.3 0-.499-.2-.499-.5s.2-.5.498-.5h2.491c.61 0 1.096.5 1.096 1.2V21c0 .6-.422 1.2-.996 1.2z"></path></g></symbol>
# <symbol id="svg-share-youtube" viewbox="0 0 30 30"><g fill-rule="evenodd" stroke="none"><path d="M13.2 17.5l4.7-2.5-4.7-2.5z"></path><path d="M15 0C6.7 0 0 6.7 0 15s6.7 15 15 15 15-6.7 15-15S23.3 0 15 0zm8.6 19.1c-.2.7-.8 1.3-1.6 1.5-1.4.4-7 .4-7 .4s-5.6 0-7-.4c-.8-.2-1.4-.8-1.6-1.5C6 17.8 6 15 6 15s0-2.8.4-4.1c.2-.8.8-1.3 1.6-1.5C9.4 9 15 9 15 9s5.6 0 7 .4c.8.2 1.4.8 1.6 1.5.4 1.3.4 4.1.4 4.1s0 2.8-.4 4.1z"></path></g></symbol>
# <symbol id="svg-signin-apple" viewbox="0 0 56 56"><path d="m 28.652475,13.009806 c 2.438195,0 5.494525,-1.699006 7.314588,-3.9643471 1.648356,-2.0529652 2.850283,-4.9200369 2.850283,-7.7871097 0,-0.38935531 -0.03434,-0.77871303 -0.103033,-1.09727518 -2.712921,0.10619674 -5.975298,1.87598558 -7.932719,4.24751678 -1.545337,1.8051924 -2.95331,4.6368681 -2.95331,7.5393362 0,0.424753 0.06869,0.849504 0.103034,0.99109 0.171693,0.0354 0.446431,0.0708 0.721157,0.0708 z m -8.585194,42.82912 c 3.331054,0 4.807709,-2.300738 8.962942,-2.300738 4.223918,0 5.151118,2.229944 8.859923,2.229944 3.640121,0 6.078319,-3.468803 8.379151,-6.866816 2.575557,-3.893554 3.640121,-7.716321 3.708804,-7.8933 -0.240381,-0.0708 -7.211565,-3.008657 -7.211565,-11.255917 0,-7.149985 5.494525,-10.371016 5.803592,-10.618789 -3.640121,-5.380187 -9.168989,-5.521772 -10.679982,-5.521772 -4.086552,0 -7.417609,2.54851 -9.512397,2.54851 -2.266491,0 -5.254141,-2.406925 -8.791241,-2.406925 -6.730794,0 -13.5646085,5.734147 -13.5646085,16.565311 0,6.725234 2.5412159,13.839824 5.6662295,18.441299 2.678579,3.893555 5.013753,7.079193 8.379152,7.079193 z" id="ï£¿" inkscape:connector-curvature="0" style="fill:#000000;fill-rule:nonzero;stroke:none;stroke-width:2.93041325"></path></symbol>
# <symbol id="svg-signin-facebook" viewbox="0 0 18 18"><g stroke="none"><path d="M18 9a9 9 0 1 0-10.406 8.89v-6.288H5.309V9h2.285V7.017c0-2.255 1.343-3.501 3.4-3.501.984 0 2.014.175 2.014.175v2.215h-1.135c-1.118 0-1.467.694-1.467 1.406V9h2.496l-.399 2.602h-2.097v6.289C14.71 17.215 18 13.492 18 9" fill="#1877f2"></path><path d="M12.503 11.602l.4-2.602h-2.497V7.312c0-.712.349-1.406 1.467-1.406h1.135V3.691s-1.03-.175-2.015-.175c-2.056 0-3.4 1.246-3.4 3.501V9H5.31v2.602h2.285v6.289a9.068 9.068 0 0 0 2.812 0V11.6h2.097" fill="#fff"></path></g></symbol>
# <symbol id="svg-signin-google" viewbox="0 0 18 18"><g fill="none" fill-rule="evenodd" stroke="none"><path d="M17.64 9.205c0-.639-.057-1.252-.164-1.841H9v3.481h4.844a4.14 4.14 0 0 1-1.796 2.716v2.259h2.908c1.702-1.567 2.684-3.875 2.684-6.615z" fill="#4285f4"></path><path d="M9 18c2.43 0 4.467-.806 5.956-2.18l-2.908-2.259c-.806.54-1.837.86-3.048.86-2.344 0-4.328-1.584-5.036-3.711H.957v2.332A8.997 8.997 0 0 0 9 18z" fill="#34a853"></path><path d="M3.964 10.71A5.41 5.41 0 0 1 3.682 9c0-.593.102-1.17.282-1.71V4.958H.957A8.996 8.996 0 0 0 0 9c0 1.452.348 2.827.957 4.042z" fill="#fbbc05"></path><path d="M9 3.58c1.321 0 2.508.454 3.44 1.345l2.582-2.58C13.463.891 11.426 0 9 0A8.997 8.997 0 0 0 .957 4.958L3.964 7.29C4.672 5.163 6.656 3.58 9 3.58z" fill="#ea4335"></path></g></symbol>
# <symbol id="svg-traveltime-bike" viewbox="0 0 140 140"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M2.917 87.5a23.333 23.333 0 1046.666 0 23.333 23.333 0 10-46.666 0zM90.417 87.5a23.333 23.333 0 1046.666 0 23.333 23.333 0 10-46.666 0z" stroke-width="5.83333"></path><path d="M64.167 87.506l35-35.006H49.583l-23.333 35h37.917L40.466 30.992M113.75 87.5l-5.524-1.867-12.56-46.48a2.917 2.917 0 013.156-3.657l14.111 1.645a5.837 5.837 0 01-1.662 11.556M35 29.167L52.5 35" stroke-width="5.83333"></path></g></symbol>
# <symbol id="svg-traveltime-car" viewbox="0 0 140 140"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M91.998 93.333h-49.84M21.968 93.333A19.92 19.92 0 012.917 73.418v-6.335a6.877 6.877 0 015.757-6.79 93.537 93.537 0 0117.576-1.96h75.833l29.464 9.824a8.09 8.09 0 015.536 7.676V87.5a5.833 5.833 0 01-5.833 5.833h-19.104M102.083 58.333l-23.333-17.5M137.083 75.833h-11.666M2.917 70h11.666M61.25 58.333l-5.833-17.5h-8.75a8.114 8.114 0 00-4.982 2.065L26.25 58.333M72.917 70h-5.834" stroke-width="5.83333"></path><path d="M90.417 87.5a11.667 11.667 0 1023.333 0 11.667 11.667 0 10-23.333 0zM20.417 87.5a11.667 11.667 0 1023.333 0 11.667 11.667 0 10-23.333 0z" stroke-width="5.83333"></path></g></symbol>
# <symbol id="svg-traveltime-transit" viewbox="0 0 140 140"><g fill="none" stroke="currentColor" stroke-linecap="round" stroke-linejoin="round"><path d="M2.917 102.083h107.916A14.583 14.583 0 00125.417 87.5c0-7.507-.035-5.664-46.667-53.958a36.237 36.237 0 00-21.875-7.292H2.917" stroke-width="5.83333"></path><path d="M111.364 67.083H64.167A14.583 14.583 0 0152.5 61.25L35 43.75h53.632M114.625 70.49a21.653 21.653 0 00-15.458 19.927 21.42 21.42 0 003.698 11.666M58.333 102.083L43.75 87.5A14.513 14.513 0 0035 84.583H2.917M137.083 113.762H2.917M55.417 102.083a8.75 8.75 0 0017.5 0M26.25 102.083a8.75 8.75 0 0017.5 0" stroke-width="5.83333"></path></g></symbol>
# <symbol id="svg-valid" viewbox="0 0 140 140"><path d="M39.94 125a19.88 19.88 0 01-15.53-7.81L2.48 92.26a10 10 0 0115-13.2l20.55 23.39a2.5 2.5 0 003.68.08l81-84.42a10.002 10.002 0 1114.5 13.78l-82.02 86.33A19.41 19.41 0 0139.94 125z" fill="currentcolor" stroke="none"></path></symbol>
# </svg>
# </body></html>

# %%
jobs = int(soup.find('span',attrs={'class':'d-md-none'}).text[0:3])
jobs
# Out:
# 127

# %%
# 20 jobs per page
for i in range(round(jobs/20)+1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
round(135/20)
# Out:
# 7

# %%
round(jobs/20)+1
# Out:
# 7

# %%
for i in range(round(jobs/20)+1):
    print('https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=' + str(i+1) +'&q=python')
# Out:
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=1&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=2&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=3&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=4&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=5&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=6&q=python
# https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=7&q=python

# %%
data = []

for i in range(round(jobs/20)+1):
    url = 'https://www.jobindex.dk/jobsoegning/storkoebenhavn?page=' + str(i) +'&q=python'
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'lxml')
    temp = soup.find_all('b')
    data.append(temp[::2])
    
data
# Out:
# [[<b>Erfaren risikoanalytiker</b>,
#   <b>System Developer at Subaio</b>,
#   <b>Senior DevOps Engineer</b>,
#   <b>Analytiker</b>,
#   <b>Statens analyseenhed søger dygtige data scientists</b>,
#   <b>Dataanalytiker/bibliometriker</b>,
#   <b>Er du motiveret og drevet af interesse for samarbejde med forskere og udvikling af forskerservices målrettet analyse og evaluering af forskning på universiteter i et tæt samspil med deres faglige og administrative miljøer?</b>,
#   <b>Metroselskabet og Hovedstadens Letbane</b>,
#   <b>ECCO Sko A/S</b>,
#   <b>PhD scholarship in Design and Modeling of Ultra-Sensitive Bio-Magnetometers</b>,
#   <b>Digitaliseringsteamet i planområdet, Bolig- og Planstyrelsen mangler en kollega</b>,
#   <b>Softwareudvikler</b>,
#   <b>Data Analyst til Customer Insights - studerende med udadvendt profil og analytisk snilde</b>,
#   <b>Skarpe konsulenter til projekter i grænselandet mellem it, finans og data</b>,
#   <b>Vi giver dig mulighed for at arbejde med de førende finansielle virksomheder med afsæt i dine kompetencer inden for finans og data. Vi er på forkant med udviklingen og hjælper vores kunder hele vejen fra strategi til implementering. </b>,
#   <b>JP/Politikens Hus</b>,
#   <b>Erhvervsministeriet</b>,
#   <b>JP/Politikens Hus</b>,
#   <b>Dribe</b>,
#   <b>Danmarks Meteorologiske Institut</b>,
#   <b>Spectro Inlets ApS</b>,
#   <b>Full stack C#/.NET (core)/Python web app developer</b>],
#  [<b>Erfaren risikoanalytiker</b>,
#   <b>System Developer at Subaio</b>,
#   <b>Senior DevOps Engineer</b>,
#   <b>Analytiker</b>,
#   <b>Statens analyseenhed søger dygtige data scientists</b>,
#   <b>Dataanalytiker/bibliometriker</b>,
#   <b>Er du motiveret og drevet af interesse for samarbejde med forskere og udvikling af forskerservices målrettet analyse og evaluering af forskning på universiteter i et tæt samspil med deres faglige og administrative miljøer?</b>,
#   <b>Metroselskabet og Hovedstadens Letbane</b>,
#   <b>ECCO Sko A/S</b>,
#   <b>PhD scholarship in Design and Modeling of Ultra-Sensitive Bio-Magnetometers</b>,
#   <b>Digitaliseringsteamet i planområdet, Bolig- og Planstyrelsen mangler en kollega</b>,
#   <b>Softwareudvikler</b>,
#   <b>Data Analyst til Customer Insights - studerende med udadvendt profil og analytisk snilde</b>,
#   <b>Skarpe konsulenter til projekter i grænselandet mellem it, finans og data</b>,
#   <b>Vi giver dig mulighed for at arbejde med de førende finansielle virksomheder med afsæt i dine kompetencer inden for finans og data. Vi er på forkant med udviklingen og hjælper vores kunder hele vejen fra strategi til implementering. </b>,
#   <b>JP/Politikens Hus</b>,
#   <b>Erhvervsministeriet</b>,
#   <b>JP/Politikens Hus</b>,
#   <b>Dribe</b>,
#   <b>Danmarks Meteorologiske Institut</b>,
#   <b>Spectro Inlets ApS</b>,
#   <b>Full stack C#/.NET (core)/Python web app developer</b>],
#  [<b>Mid-level full stack C#/.NET (core)/Javascript web app developer</b>,
#   <b>Konsulent til Bæredygtighed og Digitalisering</b>,
#   <b>Teknologisk Institut i Taastrup søger dig, som har lyst til at arbejde med avanceret dataanalyse og sensorteknologi. Du får mulighed for at sætte dit aftryk på den teknologiske udvikling inden for fødevareindustrien med deltagelse i udviklingsprojekter fra idé til implementering.</b>,
#   <b>Symphogen A/S</b>,
#   <b>Politiets Efterretningstjeneste</b>,
#   <b>PwC</b>,
#   <b>Senior Backend Engineer</b>,
#   <b>Senior DevOps Engineer</b>,
#   <b>Senior Front End Engineer (React)</b>,
#   <b>Backend Engineer</b>,
#   <b>Manager, Software Development Engineering</b>,
#   <b>Udvikler med passion for intelligent automatisering</b>,
#   <b> Er du ligesom os dybt passioneret omkring intelligent automatisering, og har du lyst til at udfolde dit talentfulde potentiale ved at hjælpe os med at videreudvikle Droids Agency og supporterer vores kunder? Hvis svaret er ja, så er det netop dig, vi søger! </b>,
#   <b>Ørsted</b>,
#   <b>A.P. Møller - Maersk A/S</b>,
#   <b>Deloitte</b>,
#   <b>Data analytiker til e-ressourcer</b>,
#   <b>Senioranalytiker til Markedsrisikomodeller</b>,
#   <b>Vil du være en del af et fagligt udfordrende og spændende miljø, hvor du har muligheden for at sætte retning og udvikle Nykredits fremtidige markedsrisikomodeller samt set-up for prismodelvalidering? </b>,
#   <b>Specsavers</b>,
#   <b>Vi har et bredt udvalg i IT-kurser, der udbydes som e-learning</b>,
#   <b>AC-medarbejder til statistikker på sundhedsområdet</b>,
#   <b>Analytiker</b>,
#   <b>Du kan kalde det en analytiker, men i virkeligheden søger vi dig, der med analyse og data gør muligheder til virkelighed.</b>],
#  [<b>Lead Software Engineer - Decarbonization - Data driven modelling</b>,
#   <b>Lead Software Engineer</b>,
#   <b>Danmarks Tekniske Universitet</b>,
#   <b>Jeudan A/S</b>,
#   <b>ECIT Labs</b>,
#   <b>A.P. Møller - Maersk A/S</b>,
#   <b>Incentive</b>,
#   <b>IT-udviklere til Operativt Teknisk Center i Indhentningsafdelingen i PET</b>,
#   <b>Senior Developer – IBM CIC</b>,
#   <b>Experienced Data Engineer</b>,
#   <b> Would you like to help Metroselskabet to ‘think smarter’ and create new knowledge by utilizing our many varied data sources to the fullest?</b>,
#   <b>A.P. Møller - Maersk A/S</b>,
#   <b>Academic Work</b>,
#   <b>nemlig.com</b>,
#   <b>Drupal-udvikler med Tech Lead-ambitioner</b>,
#   <b>Software Engineer</b>,
#   <b>Experienced engineer for product development in an ambitious high-tech start-up</b>,
#   <b>PhD scholarship in Model-based Control and Operation of Large-Scale Water Electrolyser Plants for Optimal Integration into the Power System</b>,
#   <b>Vi søger en erfaren embedded-udvikler, som nyder en god teknisk udfordring</b>,
#   <b>Senior Embedded Software Developer</b>,
#   <b>Your daily tasks will typically include: </b>,
#   <b>Deloitte</b>,
#   <b>Dataanalytiker til Visma Dinero</b>],
#  [<b>Senior Consultant with financial sector liquidity or treasury experience</b>,
#   <b>We are looking to grow our team of skilled consultants in the Financial Industry Risk &amp; Regulatory area. </b>,
#   <b>Deloitte</b>,
#   <b>DSV</b>,
#   <b>Storage Specialist - Global Large-Scale Storage Solutions</b>,
#   <b>Do you have an automation mindset? And are you specialised in storage infrastructure and applications? </b>,
#   <b>Sampension A/S</b>,
#   <b>PhD scholarship in Engineering and phenotypic profiling of beneficial aquaculture microbiomes</b>,
#   <b>Business Development Praktikant, København</b>,
#   <b> Vil du være med til at drive salgsaktiviteterne, der understøtter vores Business Development med at vinde markedsandele, identificere forretningsmuligheder og opbygge relationer? </b>,
#   <b>Centrica Energy Trading A/S</b>,
#   <b>ipvision A/S</b>,
#   <b>Danmarks Tekniske Universitet</b>,
#   <b>Egmont</b>,
#   <b>Metaceutic ApS</b>,
#   <b>Tactile Games</b>,
#   <b>UserTribe</b>,
#   <b>Zymoscope ApS</b>,
#   <b>Københavns Kommune</b>,
#   <b>Tactile Games</b>,
#   <b>Energy Machines</b>,
#   <b>KU - SCIENCE - NBI</b>,
#   <b>KU - SUND - Kbh Ø</b>],
#  [<b>Lunar</b>,
#   <b>DI</b>,
#   <b>Driversnote ApS</b>,
#   <b>Iconfinder</b>,
#   <b>KU - SUND - PANUM KBH N</b>,
#   <b>KU-SUND-Metabolismecentret</b>,
#   <b>Nexta.io</b>,
#   <b>Rodinia Generation ApS</b>,
#   <b>KU - SCIENCE BIO - BRIC</b>,
#   <b>Saxo Bank A/S</b>,
#   <b>Fourcom ApS</b>,
#   <b>KU - SUND - PANUM KBH N</b>,
#   <b>Nøie ApS</b>,
#   <b>Nøie ApS</b>,
#   <b>Danmarks Tekniske Universitet</b>,
#   <b>JazzDanmark</b>,
#   <b>Radiobotics</b>,
#   <b>Danmarks Tekniske Universitet</b>,
#   <b>Intempus</b>,
#   <b>KU-SUND-Metabolismecentret</b>],
#  [<b>AUTOproff</b>,
#   <b>Novo Nordisk</b>,
#   <b>Novo Nordisk</b>,
#   <b>SSI</b>,
#   <b>Venzo Consulting A/S</b>,
#   <b>Copenhagen Business School</b>,
#   <b>KU - SCIENCE -FOOD og NEXS</b>,
#   <b>Seculyze: Cybersecurity. Simplified</b>,
#   <b>Insai</b>,
#   <b>KU - SCIENCE - NBI</b>,
#   <b>Novo Nordisk</b>,
#   <b>Too Good To Go ApS</b>,
#   <b>Too Good To Go ApS</b>,
#   <b>Aerial Tools</b>,
#   <b>Klimate</b>,
#   <b>Banking Circle</b>,
#   <b>Novo Nordisk</b>,
#   <b>SOUNDBOKS ApS</b>,
#   <b>København Ø</b>,
#   <b>København</b>]]

# %% [markdown]
# ## Ethical Considerations
# * If a regular user can’t access it, we shouldn’t try to get it [That is considered hacking](https://www.dr.dk/nyheder/penge/gjorde-opmaerksom-paa-cpr-hul-nu-bliver-han-politianmeldt-hacking).
# * Don't hit it to fast: Essentially a DENIAL OF SERVICE attack (DOS). [Again considered hacking](https://www.dr.dk/nyheder/indland/folketingets-hjemmeside-ramt-af-hacker-angreb).
# * Add headers stating your name and email with your requests to ensure transparency.
# * Be careful with copyrighted material.
# * Fair use (take only the stuff you need)
# * If monetizing on the data, be careful not to be in direct competition with whom you are taking the data from.

# %% [markdown]
# <img src="https://github.com/snorreralund/images/raw/master/Sk%C3%A6rmbillede%202017-08-03%2014.46.32.png"/>

# %% [markdown]
# ## Interactions and Automated Browsing
# Sometimes scraping tasks demand interactions (e.g. login, scrolling, clicking), and a no XHR data can be found easily, so you need the browser to execute the scripts before you can get the data. XHR is short for XMLHttpRequest - a JavaScript API - like the one we found in the jobnet.dk exerise.
#
# Here we use the `Selenium` package in combination with the `ChromeDriver` - you can download the latest release [here](https://chromedriver.chromium.org/downloads). It allows you to animate a browser.
#
# Make sure to download the driver as well as the newest version of Selenium. "pip install selenium" should do the trick.
#
# Some developers prefer to you [geckodriver](https://github.com/mozilla/geckodriver/releases) as an alternative to `ChromeDriver`.

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager


url = 'https:google.com'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
# Out:
# [WDM] - Cache is valid for [10/11/2021]
# [WDM] - Looking for [chromedriver 95.0.4638.69 mac64] driver in cache
# [WDM] - Driver found in cache [/Users/nicklasjohansen/.wdm/drivers/chromedriver/95.0.4638.69/mac64/chromedriver]

# %%
# You can also download the driver to your computer
# Save it in your working directory and write the code

# import os
# directory = os.getcwd()
# path = os.path.join(directory, 'chromedriver')
# driver = webdriver.Chrome(executable_path=path)

# %% [markdown]
# ### Benifits from autoamting browsing
# 1. You can access data that are not directly in the HTML code but that is being generating while browsing
# 2. You can get thorugh login screens and other scraping barriers
# 3. You can automate browsing behaviour such as scrolling down

# %% [markdown]
# ## Example: nboards.dk

# %%
# step 1: load the webpage we want to scrape in our virtual browser
url = 'https://nboard.dk/search'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
# Out:
# [WDM] - Cache is valid for [10/11/2021]
# [WDM] - Looking for [chromedriver 95.0.4638.69 mac64] driver in cache
# [WDM] - Driver found in cache [/Users/nicklasjohansen/.wdm/drivers/chromedriver/95.0.4638.69/mac64/chromedriver]

# %%
# step 2: scroll down the page to load more profiles
import time

url = 'https://nboard.dk/search'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
time.sleep(3)

for i in range(5):
    time.sleep(3)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# Out:
# [WDM] - Cache is valid for [10/11/2021]
# [WDM] - Looking for [chromedriver 95.0.4638.69 mac64] driver in cache
# [WDM] - Driver found in cache [/Users/nicklasjohansen/.wdm/drivers/chromedriver/95.0.4638.69/mac64/chromedriver]

# %%
# step 3: save the soup and keep track of runtime

import time
from bs4 import BeautifulSoup

start_time = time.time()

url = 'https://nboard.dk/search'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)

for i in range(5):
    time.sleep(3)
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")

soup = BeautifulSoup(driver.page_source, 'lxml')

print("--- %s seconds ---" % round((time.time() - start_time),2))
# Out:
# [WDM] - Cache is valid for [10/11/2021]
# [WDM] - Looking for [chromedriver 95.0.4638.69 mac64] driver in cache
# [WDM] - Driver found in cache [/Users/nicklasjohansen/.wdm/drivers/chromedriver/95.0.4638.69/mac64/chromedriver]
#
# --- 19.81 seconds ---

# %%
# step 3: save the soup and keep track of runtime

import time
from bs4 import BeautifulSoup

start_time = time.time()

url = 'https://nboard.dk/search'
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)

time.sleep(3)

lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
match=False
while(match==False):
    lastCount = lenOfPage
    time.sleep(1)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    if lastCount==lenOfPage:
        match=True

time.sleep(3)

soup = BeautifulSoup(driver.page_source, 'lxml')

print("--- %s seconds ---" % round((time.time() - start_time),2))
# Out:
# [WDM] - Cache is valid for [12/08/2020]
# [WDM] - Looking for [chromedriver 84.0.4147.30 mac64] driver in cache
# [WDM] - Driver found in cache [/Users/nicklasjohansen/.wdm/drivers/chromedriver/84.0.4147.30/mac64/chromedriver]
#
# --- 193.0 seconds ---

# %%
# step 4: use the soup to generate our mapping of urls (profiles) that we want to scrape

names = soup.find_all('span', {'class': 'name'})

urls = []
for i in range(len(names)):
    temp = 'https://nboard.dk/candidate_profile/'+ str(names[i].text)
    temp = temp.replace(' ','-')
    temp = temp.replace('--','-')
    urls.append(temp)

print(len(urls))
print(urls[5])
# Out:
# 100
# https://nboard.dk/candidate_profile/Carsten-Abel

# %%
urls
# Out:
# ['https://nboard.dk/candidate_profile/Jan-Møller',
#  'https://nboard.dk/candidate_profile/Diana-Wellemberg',
#  'https://nboard.dk/candidate_profile/Jarne-Elleholm',
#  'https://nboard.dk/candidate_profile/Keld-Christensen',
#  'https://nboard.dk/candidate_profile/Maria-Fagerspang',
#  'https://nboard.dk/candidate_profile/Carsten-Abel',
#  'https://nboard.dk/candidate_profile/Hans-Melgaard',
#  'https://nboard.dk/candidate_profile/Mikkel-Vejlgaard',
#  'https://nboard.dk/candidate_profile/Annemarie-Kirk',
#  'https://nboard.dk/candidate_profile/Thomas-Grube',
#  'https://nboard.dk/candidate_profile/Laury-Kristoffersen',
#  'https://nboard.dk/candidate_profile/Mads-Wedderkopp',
#  'https://nboard.dk/candidate_profile/Mette-Villemoes-Ponty',
#  'https://nboard.dk/candidate_profile/Niels-Brinch',
#  'https://nboard.dk/candidate_profile/Christina-Andersen',
#  'https://nboard.dk/candidate_profile/Charlotte-Nytoft',
#  'https://nboard.dk/candidate_profile/Jørgen-Bøgh-Overgaard',
#  'https://nboard.dk/candidate_profile/Tinella-Svarrer',
#  'https://nboard.dk/candidate_profile/Lars-Andersen',
#  'https://nboard.dk/candidate_profile/Ulrik-Rasmussen',
#  'https://nboard.dk/candidate_profile/Bent-Ditlevsen',
#  'https://nboard.dk/candidate_profile/Peter-Hohnen',
#  'https://nboard.dk/candidate_profile/Henrik-Egede',
#  'https://nboard.dk/candidate_profile/Peter-Møller',
#  'https://nboard.dk/candidate_profile/John-Kornerup-Bang',
#  'https://nboard.dk/candidate_profile/Henrik-Christensen',
#  'https://nboard.dk/candidate_profile/Louise-Berthelsen',
#  'https://nboard.dk/candidate_profile/Nadia-Haagen-Pedersen',
#  'https://nboard.dk/candidate_profile/Steffen-Egelund-Pedersen',
#  'https://nboard.dk/candidate_profile/Susann-Krebs',
#  'https://nboard.dk/candidate_profile/Jan-Møller-Hansen',
#  'https://nboard.dk/candidate_profile/Peter-Jensen',
#  'https://nboard.dk/candidate_profile/Git-Becker',
#  'https://nboard.dk/candidate_profile/Jesper-Skou',
#  'https://nboard.dk/candidate_profile/Mogens-Nielsen',
#  'https://nboard.dk/candidate_profile/Svend-Erik-Bøytler-Rahbek',
#  'https://nboard.dk/candidate_profile/Jan-Bruun',
#  'https://nboard.dk/candidate_profile/Desireé-Højer',
#  'https://nboard.dk/candidate_profile/Michaela-Bock-Pedersen',
#  'https://nboard.dk/candidate_profile/Per-Lolk',
#  'https://nboard.dk/candidate_profile/Steen-Søndergaard',
#  'https://nboard.dk/candidate_profile/Ole-Kaas',
#  'https://nboard.dk/candidate_profile/Karina-Goos',
#  'https://nboard.dk/candidate_profile/Jens-Jakob-Sandgreen',
#  'https://nboard.dk/candidate_profile/Jan-Høstrup',
#  'https://nboard.dk/candidate_profile/Anders-Søjdis',
#  'https://nboard.dk/candidate_profile/Erik-Krage',
#  'https://nboard.dk/candidate_profile/Viggo-Janum',
#  'https://nboard.dk/candidate_profile/Claus-Holm',
#  'https://nboard.dk/candidate_profile/Arne-Burlund',
#  'https://nboard.dk/candidate_profile/Peter-A.-Wistoft',
#  'https://nboard.dk/candidate_profile/Michael-Lyng',
#  'https://nboard.dk/candidate_profile/Brian-Strøh-Tange',
#  'https://nboard.dk/candidate_profile/Lisbet-Mensa-Annan',
#  'https://nboard.dk/candidate_profile/René-Kvist',
#  'https://nboard.dk/candidate_profile/Lars-Scharf',
#  'https://nboard.dk/candidate_profile/Oscar-Borries',
#  'https://nboard.dk/candidate_profile/Claus-Jespersen',
#  'https://nboard.dk/candidate_profile/Jørgen-Svendsen-Tune',
#  'https://nboard.dk/candidate_profile/Peter-Bang',
#  'https://nboard.dk/candidate_profile/Karina-Jensen',
#  'https://nboard.dk/candidate_profile/Sverrir-Sverrisson',
#  'https://nboard.dk/candidate_profile/Hans-Jørgensen',
#  'https://nboard.dk/candidate_profile/Laura-Vilsbæk',
#  'https://nboard.dk/candidate_profile/Martin-Møller-Park',
#  'https://nboard.dk/candidate_profile/Hans-Henrik-Olsen',
#  'https://nboard.dk/candidate_profile/Claes-Hestehave',
#  'https://nboard.dk/candidate_profile/Daniel-Bæk',
#  'https://nboard.dk/candidate_profile/Kaj-Damgaard',
#  'https://nboard.dk/candidate_profile/Lone-Hass',
#  'https://nboard.dk/candidate_profile/Jeannette-Madsen',
#  'https://nboard.dk/candidate_profile/Jakob-Brüsch',
#  'https://nboard.dk/candidate_profile/Morten-Andersen',
#  'https://nboard.dk/candidate_profile/Alex-Høgh-Nielsen',
#  'https://nboard.dk/candidate_profile/Jens-Faarup',
#  'https://nboard.dk/candidate_profile/Jan-Horsager',
#  'https://nboard.dk/candidate_profile/Anders-Vidstrup',
#  'https://nboard.dk/candidate_profile/Jens-Kofoed',
#  'https://nboard.dk/candidate_profile/Dan-Brønden',
#  'https://nboard.dk/candidate_profile/Minannguaq-Zeeb',
#  'https://nboard.dk/candidate_profile/Mads-Krog-Jensen',
#  'https://nboard.dk/candidate_profile/Christian-Samsø',
#  'https://nboard.dk/candidate_profile/Carsten-Kronborg',
#  'https://nboard.dk/candidate_profile/Per-Knudsen',
#  'https://nboard.dk/candidate_profile/Lisbeth-Rækby',
#  'https://nboard.dk/candidate_profile/Jesper-Christensen',
#  'https://nboard.dk/candidate_profile/Jesper-Vinther-Fruergaard',
#  'https://nboard.dk/candidate_profile/Søren-Kargaard',
#  'https://nboard.dk/candidate_profile/Christian-Schultz',
#  'https://nboard.dk/candidate_profile/Mads-Middelboe',
#  'https://nboard.dk/candidate_profile/Jakob-Skovgaard',
#  'https://nboard.dk/candidate_profile/Christian-Meldgaard',
#  'https://nboard.dk/candidate_profile/Carsten-Nielsen',
#  'https://nboard.dk/candidate_profile/Peter-Berendsen-Svarrer',
#  'https://nboard.dk/candidate_profile/Susanne-Juhl',
#  'https://nboard.dk/candidate_profile/Stine-Elmkvist',
#  'https://nboard.dk/candidate_profile/Søren-Hesselberg-Jensen',
#  'https://nboard.dk/candidate_profile/Leif-Vestergaard',
#  'https://nboard.dk/candidate_profile/Klaus-Hansen',
#  'https://nboard.dk/candidate_profile/Carsten-Nielsen']

# %%
# step 5: scraping profiles 
import requests
import pandas as pd

start_time = time.time()

name = []
subtitle = []
location = []
resume = []

for i in range(5): #len(urls)
    response = requests.get(urls[i])
    html = response.text
    
    if 'Internal server error' in html:
        continue
    
    soup = BeautifulSoup(html, "html.parser")
    name.append(soup.find('title').text)
    subtitle.append(soup.find('span', {'class': 'sub-title'}).text)
    location.append(soup.find('span', {'class': 'location'}).text)
    resume.append(soup.find('span', {'class': 'resume'}).text)

df = pd.DataFrame({'name':name, 
                   'subtitle':subtitle, 
                   'location':location, 
                   'resume':resume})

print("--- %s seconds ---" % round((time.time() - start_time),2))

df
# Out:
# --- 24.8 seconds ---
#                name                                           subtitle  \
# 0        Jan Møller  Salg, ledelse og iværksætter - FINTECH, TRADIN...
# 1  Diana Wellemberg  Erfaring med Digitalisering, Bæredygtighed og ...
# 2    Jarne Elleholm     Erfaren Life Science bestyrelsesformand/medlem
#
#              location                                             resume
# 0     Odense, Danmark  Igennem mange års erfaring med international s...
# 1  København, Danmark  Jeg har mere end 13 års erfaring indenfor Supp...
# 2   Gentofte, Danmark  Skal du igang med at kommercialisere din life ...

# %% [markdown]
# ### Next level scrapers
#
# You have know learned some of the fundamentals of collecting and parsing data and should be well suited for your exam project. Though I find it important to adress that you might run into some challenges that we have not learn dealing with yet. Facebook, LinkedIn, Google and all the other big tech firms are battling scrapers and has done all kinds of thing to make it hard for us to steal public data on their sites. I have found som article that you might find interessting.
#
# - [Most Commonly used techniques to Prevent Scraping:](https://medium.com/@betoayesa/using-the-content-as-an-anti-scrape-weapon-draft-9bb10cd30e5c)
# - [Advanced Web Scraping Tactics](https://www.pluralsight.com/guides/advanced-web-scraping-tactics-python-playbook)
# - [Scraping Sites That Use JavaScript and AJAX](https://oup-arc.com/protected/files/content/file/1505319833942-CH9---Scraping-Sites-that-Use-JavaScript-and-AJAX.pdf)
# - [Get Started Scraping LinkedIn With Python and Selenium](https://medium.com/nerd-for-tech/linked-in-web-scraper-using-selenium-15189959b3ba)

# %% [markdown]
# # Associated Readings+
#
# Readings:
# - [Python for Data Analysis, chapter 6](https://bedford-computing.co.uk/learning/wp-content/uploads/2015/10/Python-for-Data-Analysis.pdf)
# - [A Practical Introduction to Web Scraping in Python](https://realpython.com/python-web-scraping-practical-introduction/)
# - [An introduction to web scraping with Python](https://towardsdatascience.com/an-introduction-to-web-scraping-with-python-a2601e8619e5)
# - [Introduction to Web Scraping using Selenium](https://medium.com/the-andela-way/introduction-to-web-scraping-using-selenium-7ec377a8cf72)

# %% [markdown]
# # session_9_exercises.ipynb
# Will be uploaded on github.
# - Method 1: sync your cloned repo
# - Method 2: download from git repo
#
# `Remember` to create a local copy of the notebook

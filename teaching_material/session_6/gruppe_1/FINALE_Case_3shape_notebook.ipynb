# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math as math

# %%
#Importerer appendix 3
df_country = pd.read_excel('Appendix_3.xlsx')
df_country
# Out:
#               Country     Language  Licenses  Meaningless_ID
# 0       United States     American    7865.0             1.0
# 1              France       French    3410.0             4.0
# 2               Korea       Korean    2448.0             NaN
# 3               Italy      Italian    1712.0             7.0
# 4             Germany       German    1590.0             2.0
# ..                ...          ...       ...             ...
# 80        Puerto Rico      English       4.0             8.0
# 81      Liechtenstein       German       3.0             6.0
# 82             Latvia      Russian       2.0             4.0
# 83         Kazakhstan      Russian       0.0             3.0
# 84          Vesterbro  Københavnsk       NaN             0.0
#
# [85 rows x 4 columns]

# %%
#Fjerner meaningless_ID. Fjerner 'Vesterbro, Københavnsk'. Tjekker om det er fjernet.
del df_country['Meaningless_ID']
df_country = df_country.drop([84])
df_country
#Det er fjernet
# Out:
#               Country  Language  Licenses
# 0       United States  American    7865.0
# 1              France    French    3410.0
# 2               Korea    Korean    2448.0
# 3               Italy   Italian    1712.0
# 4             Germany    German    1590.0
# ..                ...       ...       ...
# 79              Nepal    Nepali       6.0
# 80        Puerto Rico   English       4.0
# 81      Liechtenstein    German       3.0
# 82             Latvia   Russian       2.0
# 83         Kazakhstan   Russian       0.0
#
# [84 rows x 3 columns]

# %%
#Sorterer data efter sprog i alfabetisk rækkefølge for at skabe overblik
df_country.head(50).sort_values(['Language'], ascending=True)
# Out:
#                      Country           Language  Licenses
# 0              United States           American    7865.0
# 46                   Morocco             Arabic      44.0
# 48                     Egypt             Arabic      40.0
# 26                   Lebanon             Arabic     137.0
# 6                      China           Chineese    1293.0
# 44                   Croatia           Croatian      49.0
# 36            Czech Republic              Czech      78.0
# 37              South Africa            English      74.0
# 18                    Norway            English     274.0
# 31               New Zealand            English     108.0
# 27                    Israel            English     126.0
# 43                  Pakistan            English      54.0
# 45                   Iceland            English      49.0
# 21                   Belgium            English     234.0
# 19                 Singapore            English     263.0
# 38                   Finland            English      74.0
# 17                    Sweden            English     274.0
# 24                     India            English     191.0
# 15      United Arab Emirates            English     317.0
# 5                  Australia            English    1493.0
# 7             United Kingdom            English    1221.0
# 9                     Canada            English     782.0
# 10               Netherlands            English     659.0
# 11                   Ireland            English     634.0
# 49                    Kuwait            English      35.0
# 13                   Denmark            English     380.0
# 1                     France             French    3410.0
# 23                   Austria             German     195.0
# 4                    Germany             German    1590.0
# 14               Switzerland             German     317.0
# 32                    Greece              Greek     103.0
# 41                   Hungary          Hungarian      54.0
# 3                      Italy            Italian    1712.0
# 25                     Japan           Japanese     180.0
# 2                      Korea             Korean    2448.0
# 39                 Lithuania          Lithanian      69.0
# 20                    Taiwan  Mandarin(Chinese)     263.0
# 28             Hong Kong SAR  Mandarin(Chinese)     112.0
# 12                    Poland             Polish     420.0
# 16                    Brazil         Portuguese     278.0
# 33                   Romania           Romanian     103.0
# 40                    Russia            Russian      60.0
# 42                   Ukraine            Russian      54.0
# 30                  Slovakia             Slovak     108.0
# 35                    Mexico            Spanish      89.0
# 47                  Colombia            Spanish      40.0
# 22                  Thailand               Thai     225.0
# 34                    Turkey            Turkish      92.0
# 29                   Vietnam         Vietnamese     112.0
# 8                      Spain            spanish     805.0

# %%
#Ensarter og korrigerer værdier i sprog-kollonnen, da det varierer, hvordan sprog er formuleret eller angivet
df_country['Language'] = df_country['Language']\
    .replace(['American'],'English')\
    .replace(['Mandarin(Chinese)'], 'Chinese')\
    .replace(['spanish'], 'Spanish')\
    .replace(['chineese'], 'Chinese')\
    .replace(['Chineese'], 'Chinese')

df_country_sort = df_country.sort_values(['Language'], ascending=True)

# %%
#Sikrer at 'Country er en string-value'
df_country_sort['Country']=df_country_sort['Country'].astype("string")
df_country_sort.dtypes
# Out:
# Country      string
# Language     object
# Licenses    float64
# dtype: object

# %%
#Grupperer lande efter deres geografiske lokalisation for senere at allokere supportcentre, der er svarende til tidszoner
def country_cat(variable):
    if variable in ['Lithuania','Monaco','Croatia','France','Italy','Germany','United Kingdom','Spain','Netherlands','Ireland','Poland','Denmark','Switzerland','Sweden','Norway','Belgium','Austria','Slovakia','Greece','Romania','Czech Republic','Finland','Lithaunia','Hungary','Ukraine','Crotia','Iceland','Bulgaria','Luxembourg','Serbia','Slovenia','Estonia','Portugal','Cyprus','Armenien','Liechtenstein','Latvia']:
        return 'Europe'
    if variable in ['Israel','United Arab Emirates','Lebanon','Pakistan','Kuwait','Lebanon','Morocco','Egypt','Tunisia','Saudi Arabia','Jordan','Algeria','Iraq','Turkey','Iran']:
        return 'Middle East'
    if variable in ['Thailand','Singapore','Indonesia','Australia','New Zealand','China','Korea','Philippines','Myanmar','Malaysia','India','Japan','Taiwan','Hong Kong SAR','Nepal','Vietnam']:
        return 'Pacific'
    if variable in ['Armenia','Moldova','Georgia','Azerbaijan','Kazakhstan','Russia']:
        return 'Russian'
    if variable in ['United States','Canada']:
        return 'North America'
    if variable in ['South Africa']:
        return 'Africa'
    else:
        return 'South America'
    
    
#Fjerner de mellemrum, der er i starten af landenes navne, så definitionen ovenfor kan virke   
df_country_sort['Country']= df_country_sort['Country'].str.lstrip()

#Indsætter område som ny kollonne i dataframe
df_country_sort['Area'] = df_country_sort['Country'].apply(country_cat)
df_country_sort.tail(60)
# Out:
#                  Country    Language  Licenses           Area
# 0          United States     English    7865.0  North America
# 21               Belgium     English     234.0         Europe
# 80           Puerto Rico     English       4.0  South America
# 5              Australia     English    1493.0        Pacific
# 7         United Kingdom     English    1221.0         Europe
# 9                 Canada     English     782.0  North America
# 10           Netherlands     English     659.0         Europe
# 76              Malaysia     English       6.0        Pacific
# 13               Denmark     English     380.0         Europe
# 11               Ireland     English     634.0         Europe
# 15  United Arab Emirates     English     317.0    Middle East
# 17                Sweden     English     274.0         Europe
# 18                Norway     English     274.0         Europe
# 19             Singapore     English     263.0        Pacific
# 74                Monaco      French       6.0         Europe
# 1                 France      French    3410.0         Europe
# 75               Georgia    Georgian       6.0        Russian
# 53            Luxembourg      German      26.0         Europe
# 4                Germany      German    1590.0         Europe
# 81         Liechtenstein      German       3.0         Europe
# 14           Switzerland      German     317.0         Europe
# 23               Austria      German     195.0         Europe
# 32                Greece       Greek     103.0         Europe
# 66                Cyprus       Greek       9.0         Europe
# 41               Hungary   Hungarian      54.0         Europe
# 64             Indonesia  Indonesian       9.0        Pacific
# 3                  Italy     Italian    1712.0         Europe
# 25                 Japan    Japanese     180.0        Pacific
# 2                  Korea      Korean    2448.0        Pacific
# 39             Lithuania   Lithanian      69.0         Europe
# 79                 Nepal      Nepali       6.0        Pacific
# 51                  Iran     Persian      29.0    Middle East
# 12                Poland      Polish     420.0         Europe
# 16                Brazil  Portuguese     278.0  South America
# 60              Portugal  Portuguese      15.0         Europe
# 33               Romania    Romanian     103.0         Europe
# 42               Ukraine     Russian      54.0         Europe
# 72            Azerbaijan     Russian       9.0        Russian
# 71               Moldova     Russian       9.0        Russian
# 69               Armenia     Russian       9.0        Russian
# 83            Kazakhstan     Russian       0.0        Russian
# 82                Latvia     Russian       2.0         Europe
# 40                Russia     Russian      60.0        Russian
# 57               Estonia     Russian      20.0         Europe
# 54                Serbia     Serbian      20.0         Europe
# 30              Slovakia      Slovak     108.0         Europe
# 55              Slovenia   Slovenian      20.0         Europe
# 8                  Spain     Spanish     805.0         Europe
# 77             Venezuela     Spanish       6.0  South America
# 35                Mexico     Spanish      89.0  South America
# 62            Costa Rica     Spanish      15.0  South America
# 58             Argentina     Spanish      20.0  South America
# 70               Bolivia     Spanish       9.0  South America
# 61               Uruguay     Spanish      15.0  South America
# 68              Paraguay     Spanish       9.0  South America
# 47              Colombia     Spanish      40.0  South America
# 63                 Chile     Spanish       9.0  South America
# 22              Thailand        Thai     225.0        Pacific
# 34                Turkey     Turkish      92.0    Middle East
# 29               Vietnam  Vietnamese     112.0        Pacific

# %%
#Her parres sprog med geografisk lokalisation, så det er nemmere at finde ud af, hvilket supportcenter, der kan knyttes til hvert land
df_country_sort["Language & area"] = df_country_sort[["Language", "Area"]].agg(', '.join, axis=1)
df_country_sort.head(60)
# Out:
#                  Country    Language  Licenses           Area  \
# 48                 Egypt      Arabic      40.0    Middle East
# 73               Algeria      Arabic       9.0    Middle East
# 26               Lebanon      Arabic     137.0    Middle East
# 65                Jordan      Arabic       9.0    Middle East
# 59          Saudi Arabia      Arabic      15.0    Middle East
# 56               Tunisia      Arabic      20.0    Middle East
# 78                  Iraq      Arabic       6.0    Middle East
# 46               Morocco      Arabic      44.0    Middle East
# 50              Bulgaria   Bulgarian      29.0         Europe
# 6                  China     Chinese    1293.0        Pacific
# 28         Hong Kong SAR     Chinese     112.0        Pacific
# 20                Taiwan     Chinese     263.0        Pacific
# 44               Croatia    Croatian      49.0         Europe
# 36        Czech Republic       Czech      78.0         Europe
# 38               Finland     English      74.0         Europe
# 37          South Africa     English      74.0         Africa
# 24                 India     English     191.0        Pacific
# 49                Kuwait     English      35.0    Middle East
# 43              Pakistan     English      54.0    Middle East
# 31           New Zealand     English     108.0        Pacific
# 67               Myanmar     English       9.0        Pacific
# 27                Israel     English     126.0    Middle East
# 45               Iceland     English      49.0         Europe
# 52           Philippines     English      26.0        Pacific
# 0          United States     English    7865.0  North America
# 21               Belgium     English     234.0         Europe
# 80           Puerto Rico     English       4.0  South America
# 5              Australia     English    1493.0        Pacific
# 7         United Kingdom     English    1221.0         Europe
# 9                 Canada     English     782.0  North America
# 10           Netherlands     English     659.0         Europe
# 76              Malaysia     English       6.0        Pacific
# 13               Denmark     English     380.0         Europe
# 11               Ireland     English     634.0         Europe
# 15  United Arab Emirates     English     317.0    Middle East
# 17                Sweden     English     274.0         Europe
# 18                Norway     English     274.0         Europe
# 19             Singapore     English     263.0        Pacific
# 74                Monaco      French       6.0         Europe
# 1                 France      French    3410.0         Europe
# 75               Georgia    Georgian       6.0        Russian
# 53            Luxembourg      German      26.0         Europe
# 4                Germany      German    1590.0         Europe
# 81         Liechtenstein      German       3.0         Europe
# 14           Switzerland      German     317.0         Europe
# 23               Austria      German     195.0         Europe
# 32                Greece       Greek     103.0         Europe
# 66                Cyprus       Greek       9.0         Europe
# 41               Hungary   Hungarian      54.0         Europe
# 64             Indonesia  Indonesian       9.0        Pacific
# 3                  Italy     Italian    1712.0         Europe
# 25                 Japan    Japanese     180.0        Pacific
# 2                  Korea      Korean    2448.0        Pacific
# 39             Lithuania   Lithanian      69.0         Europe
# 79                 Nepal      Nepali       6.0        Pacific
# 51                  Iran     Persian      29.0    Middle East
# 12                Poland      Polish     420.0         Europe
# 16                Brazil  Portuguese     278.0  South America
# 60              Portugal  Portuguese      15.0         Europe
# 33               Romania    Romanian     103.0         Europe
#
#               Language & area
# 48        Arabic, Middle East
# 73        Arabic, Middle East
# 26        Arabic, Middle East
# 65        Arabic, Middle East
# 59        Arabic, Middle East
# 56        Arabic, Middle East
# 78        Arabic, Middle East
# 46        Arabic, Middle East
# 50          Bulgarian, Europe
# 6            Chinese, Pacific
# 28           Chinese, Pacific
# 20           Chinese, Pacific
# 44           Croatian, Europe
# 36              Czech, Europe
# 38            English, Europe
# 37            English, Africa
# 24           English, Pacific
# 49       English, Middle East
# 43       English, Middle East
# 31           English, Pacific
# 67           English, Pacific
# 27       English, Middle East
# 45            English, Europe
# 52           English, Pacific
# 0      English, North America
# 21            English, Europe
# 80     English, South America
# 5            English, Pacific
# 7             English, Europe
# 9      English, North America
# 10            English, Europe
# 76           English, Pacific
# 13            English, Europe
# 11            English, Europe
# 15       English, Middle East
# 17            English, Europe
# 18            English, Europe
# 19           English, Pacific
# 74             French, Europe
# 1              French, Europe
# 75          Georgian, Russian
# 53             German, Europe
# 4              German, Europe
# 81             German, Europe
# 14             German, Europe
# 23             German, Europe
# 32              Greek, Europe
# 66              Greek, Europe
# 41          Hungarian, Europe
# 64        Indonesian, Pacific
# 3             Italian, Europe
# 25          Japanese, Pacific
# 2             Korean, Pacific
# 39          Lithanian, Europe
# 79            Nepali, Pacific
# 51       Persian, Middle East
# 12             Polish, Europe
# 16  Portuguese, South America
# 60         Portuguese, Europe
# 33           Romanian, Europe

# %%
#Her er en liste over unikke værdier i ovenstående dataframe, hvad angår land/område-kombinationer.
#Dette bruges til at skabe overblik over, hvordan supportcentre kan allokeres
df_country_sort['Language & area'].unique()
# Out:
# array(['Arabic, Middle East', 'Bulgarian, Europe', 'Chinese, Pacific',
#        'Croatian, Europe', 'Czech, Europe', 'English, Europe',
#        'English, Africa', 'English, Pacific', 'English, Middle East',
#        'English, North America', 'English, South America',
#        'French, Europe', 'Georgian, Russian', 'German, Europe',
#        'Greek, Europe', 'Hungarian, Europe', 'Indonesian, Pacific',
#        'Italian, Europe', 'Japanese, Pacific', 'Korean, Pacific',
#        'Lithanian, Europe', 'Nepali, Pacific', 'Persian, Middle East',
#        'Polish, Europe', 'Portuguese, South America',
#        'Portuguese, Europe', 'Romanian, Europe', 'Russian, Europe',
#        'Russian, Russian', 'Serbian, Europe', 'Slovak, Europe',
#        'Slovenian, Europe', 'Spanish, Europe', 'Spanish, South America',
#        'Thai, Pacific', 'Turkish, Middle East', 'Vietnamese, Pacific'],
#       dtype=object)

# %%
#Nu fordeler vi de enkelte sprogområder til et specifikt supportcenter
#Danmark udelades, da det 1) er dyrt, 2) taler relativt få sprog og 3) Ukraine kan dække nogenlunde samme områder (og Ukraine har flere sprog)
def country_service(varcomb):
    if varcomb in ['Chinese, Pacific','English, Pacific','Japanese, Pacific', 'Korean, Pacific']:
        return 'China'
    if varcomb in ['English, Europe', 'English, Africa','English, Middle East','French, Europe','German, Europe','Italian, Europe','Russian, Europe','Russian, Russian','Spanish, Europe']:
        return 'Ukraine'
    if varcomb in ['English, North America', 'English, South America']:
        return 'USA'
    if varcomb in ['Portuguese, South America','Spanish, South America']:
        return 'Colombia'
    else:
        return np.nan
    
#Vi forudsætter hermed, at man i USA's supportcenter ikke kan tale spansk eller portugesisk
        
#Indsætter ny kollone, hvor hvert land har fået tildelt et supportcenter. NaN betyder, at der ikke kan tilknytttes et supportcenter.
#Der er taget hensyn til tidszoner
df_country_sort['Support Center'] = df_country_sort['Language & area'].apply(country_service)
df_country_sort.head(60)
# Out:
#                  Country    Language  Licenses           Area  \
# 48                 Egypt      Arabic      40.0    Middle East
# 73               Algeria      Arabic       9.0    Middle East
# 26               Lebanon      Arabic     137.0    Middle East
# 65                Jordan      Arabic       9.0    Middle East
# 59          Saudi Arabia      Arabic      15.0    Middle East
# 56               Tunisia      Arabic      20.0    Middle East
# 78                  Iraq      Arabic       6.0    Middle East
# 46               Morocco      Arabic      44.0    Middle East
# 50              Bulgaria   Bulgarian      29.0         Europe
# 6                  China     Chinese    1293.0        Pacific
# 28         Hong Kong SAR     Chinese     112.0        Pacific
# 20                Taiwan     Chinese     263.0        Pacific
# 44               Croatia    Croatian      49.0         Europe
# 36        Czech Republic       Czech      78.0         Europe
# 38               Finland     English      74.0         Europe
# 37          South Africa     English      74.0         Africa
# 24                 India     English     191.0        Pacific
# 49                Kuwait     English      35.0    Middle East
# 43              Pakistan     English      54.0    Middle East
# 31           New Zealand     English     108.0        Pacific
# 67               Myanmar     English       9.0        Pacific
# 27                Israel     English     126.0    Middle East
# 45               Iceland     English      49.0         Europe
# 52           Philippines     English      26.0        Pacific
# 0          United States     English    7865.0  North America
# 21               Belgium     English     234.0         Europe
# 80           Puerto Rico     English       4.0  South America
# 5              Australia     English    1493.0        Pacific
# 7         United Kingdom     English    1221.0         Europe
# 9                 Canada     English     782.0  North America
# 10           Netherlands     English     659.0         Europe
# 76              Malaysia     English       6.0        Pacific
# 13               Denmark     English     380.0         Europe
# 11               Ireland     English     634.0         Europe
# 15  United Arab Emirates     English     317.0    Middle East
# 17                Sweden     English     274.0         Europe
# 18                Norway     English     274.0         Europe
# 19             Singapore     English     263.0        Pacific
# 74                Monaco      French       6.0         Europe
# 1                 France      French    3410.0         Europe
# 75               Georgia    Georgian       6.0        Russian
# 53            Luxembourg      German      26.0         Europe
# 4                Germany      German    1590.0         Europe
# 81         Liechtenstein      German       3.0         Europe
# 14           Switzerland      German     317.0         Europe
# 23               Austria      German     195.0         Europe
# 32                Greece       Greek     103.0         Europe
# 66                Cyprus       Greek       9.0         Europe
# 41               Hungary   Hungarian      54.0         Europe
# 64             Indonesia  Indonesian       9.0        Pacific
# 3                  Italy     Italian    1712.0         Europe
# 25                 Japan    Japanese     180.0        Pacific
# 2                  Korea      Korean    2448.0        Pacific
# 39             Lithuania   Lithanian      69.0         Europe
# 79                 Nepal      Nepali       6.0        Pacific
# 51                  Iran     Persian      29.0    Middle East
# 12                Poland      Polish     420.0         Europe
# 16                Brazil  Portuguese     278.0  South America
# 60              Portugal  Portuguese      15.0         Europe
# 33               Romania    Romanian     103.0         Europe
#
#               Language & area Support Center
# 48        Arabic, Middle East            NaN
# 73        Arabic, Middle East            NaN
# 26        Arabic, Middle East            NaN
# 65        Arabic, Middle East            NaN
# 59        Arabic, Middle East            NaN
# 56        Arabic, Middle East            NaN
# 78        Arabic, Middle East            NaN
# 46        Arabic, Middle East            NaN
# 50          Bulgarian, Europe            NaN
# 6            Chinese, Pacific          China
# 28           Chinese, Pacific          China
# 20           Chinese, Pacific          China
# 44           Croatian, Europe            NaN
# 36              Czech, Europe            NaN
# 38            English, Europe        Ukraine
# 37            English, Africa        Ukraine
# 24           English, Pacific          China
# 49       English, Middle East        Ukraine
# 43       English, Middle East        Ukraine
# 31           English, Pacific          China
# 67           English, Pacific          China
# 27       English, Middle East        Ukraine
# 45            English, Europe        Ukraine
# 52           English, Pacific          China
# 0      English, North America            USA
# 21            English, Europe        Ukraine
# 80     English, South America            USA
# 5            English, Pacific          China
# 7             English, Europe        Ukraine
# 9      English, North America            USA
# 10            English, Europe        Ukraine
# 76           English, Pacific          China
# 13            English, Europe        Ukraine
# 11            English, Europe        Ukraine
# 15       English, Middle East        Ukraine
# 17            English, Europe        Ukraine
# 18            English, Europe        Ukraine
# 19           English, Pacific          China
# 74             French, Europe        Ukraine
# 1              French, Europe        Ukraine
# 75          Georgian, Russian            NaN
# 53             German, Europe        Ukraine
# 4              German, Europe        Ukraine
# 81             German, Europe        Ukraine
# 14             German, Europe        Ukraine
# 23             German, Europe        Ukraine
# 32              Greek, Europe            NaN
# 66              Greek, Europe            NaN
# 41          Hungarian, Europe            NaN
# 64        Indonesian, Pacific            NaN
# 3             Italian, Europe        Ukraine
# 25          Japanese, Pacific          China
# 2             Korean, Pacific          China
# 39          Lithanian, Europe            NaN
# 79            Nepali, Pacific            NaN
# 51       Persian, Middle East            NaN
# 12             Polish, Europe            NaN
# 16  Portuguese, South America       Colombia
# 60         Portuguese, Europe            NaN
# 33           Romanian, Europe            NaN

# %%
#Fjerner NaN-værdier (dvs. lande der ikke sprogligt kan dækkes)
df_support = df_country_sort.dropna(axis=0)
df_support.head(60)
# Out:
#                  Country    Language  Licenses           Area  \
# 6                  China     Chinese    1293.0        Pacific
# 28         Hong Kong SAR     Chinese     112.0        Pacific
# 20                Taiwan     Chinese     263.0        Pacific
# 38               Finland     English      74.0         Europe
# 37          South Africa     English      74.0         Africa
# 24                 India     English     191.0        Pacific
# 49                Kuwait     English      35.0    Middle East
# 43              Pakistan     English      54.0    Middle East
# 31           New Zealand     English     108.0        Pacific
# 67               Myanmar     English       9.0        Pacific
# 27                Israel     English     126.0    Middle East
# 45               Iceland     English      49.0         Europe
# 52           Philippines     English      26.0        Pacific
# 0          United States     English    7865.0  North America
# 21               Belgium     English     234.0         Europe
# 80           Puerto Rico     English       4.0  South America
# 5              Australia     English    1493.0        Pacific
# 7         United Kingdom     English    1221.0         Europe
# 9                 Canada     English     782.0  North America
# 10           Netherlands     English     659.0         Europe
# 76              Malaysia     English       6.0        Pacific
# 13               Denmark     English     380.0         Europe
# 11               Ireland     English     634.0         Europe
# 15  United Arab Emirates     English     317.0    Middle East
# 17                Sweden     English     274.0         Europe
# 18                Norway     English     274.0         Europe
# 19             Singapore     English     263.0        Pacific
# 74                Monaco      French       6.0         Europe
# 1                 France      French    3410.0         Europe
# 53            Luxembourg      German      26.0         Europe
# 4                Germany      German    1590.0         Europe
# 81         Liechtenstein      German       3.0         Europe
# 14           Switzerland      German     317.0         Europe
# 23               Austria      German     195.0         Europe
# 3                  Italy     Italian    1712.0         Europe
# 25                 Japan    Japanese     180.0        Pacific
# 2                  Korea      Korean    2448.0        Pacific
# 16                Brazil  Portuguese     278.0  South America
# 42               Ukraine     Russian      54.0         Europe
# 72            Azerbaijan     Russian       9.0        Russian
# 71               Moldova     Russian       9.0        Russian
# 69               Armenia     Russian       9.0        Russian
# 83            Kazakhstan     Russian       0.0        Russian
# 82                Latvia     Russian       2.0         Europe
# 40                Russia     Russian      60.0        Russian
# 57               Estonia     Russian      20.0         Europe
# 8                  Spain     Spanish     805.0         Europe
# 77             Venezuela     Spanish       6.0  South America
# 35                Mexico     Spanish      89.0  South America
# 62            Costa Rica     Spanish      15.0  South America
# 58             Argentina     Spanish      20.0  South America
# 70               Bolivia     Spanish       9.0  South America
# 61               Uruguay     Spanish      15.0  South America
# 68              Paraguay     Spanish       9.0  South America
# 47              Colombia     Spanish      40.0  South America
# 63                 Chile     Spanish       9.0  South America
#
#               Language & area Support Center
# 6            Chinese, Pacific          China
# 28           Chinese, Pacific          China
# 20           Chinese, Pacific          China
# 38            English, Europe        Ukraine
# 37            English, Africa        Ukraine
# 24           English, Pacific          China
# 49       English, Middle East        Ukraine
# 43       English, Middle East        Ukraine
# 31           English, Pacific          China
# 67           English, Pacific          China
# 27       English, Middle East        Ukraine
# 45            English, Europe        Ukraine
# 52           English, Pacific          China
# 0      English, North America            USA
# 21            English, Europe        Ukraine
# 80     English, South America            USA
# 5            English, Pacific          China
# 7             English, Europe        Ukraine
# 9      English, North America            USA
# 10            English, Europe        Ukraine
# 76           English, Pacific          China
# 13            English, Europe        Ukraine
# 11            English, Europe        Ukraine
# 15       English, Middle East        Ukraine
# 17            English, Europe        Ukraine
# 18            English, Europe        Ukraine
# 19           English, Pacific          China
# 74             French, Europe        Ukraine
# 1              French, Europe        Ukraine
# 53             German, Europe        Ukraine
# 4              German, Europe        Ukraine
# 81             German, Europe        Ukraine
# 14             German, Europe        Ukraine
# 23             German, Europe        Ukraine
# 3             Italian, Europe        Ukraine
# 25          Japanese, Pacific          China
# 2             Korean, Pacific          China
# 16  Portuguese, South America       Colombia
# 42            Russian, Europe        Ukraine
# 72           Russian, Russian        Ukraine
# 71           Russian, Russian        Ukraine
# 69           Russian, Russian        Ukraine
# 83           Russian, Russian        Ukraine
# 82            Russian, Europe        Ukraine
# 40           Russian, Russian        Ukraine
# 57            Russian, Europe        Ukraine
# 8             Spanish, Europe        Ukraine
# 77     Spanish, South America       Colombia
# 35     Spanish, South America       Colombia
# 62     Spanish, South America       Colombia
# 58     Spanish, South America       Colombia
# 70     Spanish, South America       Colombia
# 61     Spanish, South America       Colombia
# 68     Spanish, South America       Colombia
# 47     Spanish, South America       Colombia
# 63     Spanish, South America       Colombia

# %%
#Udregner hvor mange supportcentre, der kan ligge pr. land
#Her antager vi, at etableringsomkostningerne i de enkelte lande = 0 
df_support.groupby('Support Center')['Licenses'].sum()
# Out:
# Support Center
# China        6392.0
# Colombia      490.0
# USA          8651.0
# Ukraine     12632.0
# Name: Licenses, dtype: float64

# %%
#Indlæser data fra appendix 2
#Antagelse: Totale omkostninger er indfanget (imputed) i medarbejderomkostninger
App2 = pd.read_excel('Appendix_2.xlsx')
a2 = App2.drop([5])
a2['Avg Annual Employee cost'] = (a2['Total cost']/a2['Average FTE'])
a2['Avg Monthly Employee cost'] = a2['Avg Annual Employee cost']/12
a2['Support Center'] = a2['Support Center'].astype("string")
a2
# Out:
#   Support Center Total cost Average FTE Avg Annual Employee cost  \
# 0       Denmark     2150000           5                 430000.0
# 1         China     2500000          10                 250000.0
# 2           USA      750000           9             83333.333333
# 3      Colombia     2100000          21                 100000.0
# 4       Ukraine      650000          38             17105.263158
#
#   Avg Monthly Employee cost
# 0              35833.333333
# 1              20833.333333
# 2               6944.444444
# 3               8333.333333
# 4               1425.438596

# %%
#Laver variable for de 30 % som ikke længere går til reseller, men som går til 3shape direkte
profit_margin = 2000*0.3

# %%
#Udregner profit-loss balance for hvert land pba. tallen fra ovenstående dataframe.
#Vi udregner ud fra, hvad det minimale antal medarbejdere, der skal til for at dække licenserne. Dette giver det mest omkostningseffektive resultat.
a4 = pd.DataFrame({'No. of employees': np.arange(3,43,1), 'Licenses serviced': np.arange(300, 8200, 200)})
a4['Extra revenue'] = a4['Licenses serviced']*profit_margin
a4['PL-balance_DK'] = a4['Extra revenue'] - (430000*a4['No. of employees'])
a4['PL-balance_CN'] = a4['Extra revenue'] - (250000*a4['No. of employees'])
a4['PL-balance_US'] = a4['Extra revenue'] - (83333.3*a4['No. of employees'])
a4['PL-balance_CO'] = a4['Extra revenue'] - (100000*a4['No. of employees'])
a4['PL-balance_UKR'] = a4['Extra revenue'] - (17105.3*a4['No. of employees'])
a4.astype(int).round(0)
# Out:
#     No. of employees  Licenses serviced  Extra revenue  PL-balance_DK  \
# 0                  3                300         180000       -1110000
# 1                  4                500         300000       -1420000
# 2                  5                700         420000       -1730000
# 3                  6                900         540000       -2040000
# 4                  7               1100         660000       -2350000
# 5                  8               1300         780000       -2660000
# 6                  9               1500         900000       -2970000
# 7                 10               1700        1020000       -3280000
# 8                 11               1900        1140000       -3590000
# 9                 12               2100        1260000       -3900000
# 10                13               2300        1380000       -4210000
# 11                14               2500        1500000       -4520000
# 12                15               2700        1620000       -4830000
# 13                16               2900        1740000       -5140000
# 14                17               3100        1860000       -5450000
# 15                18               3300        1980000       -5760000
# 16                19               3500        2100000       -6070000
# 17                20               3700        2220000       -6380000
# 18                21               3900        2340000       -6690000
# 19                22               4100        2460000       -7000000
# 20                23               4300        2580000       -7310000
# 21                24               4500        2700000       -7620000
# 22                25               4700        2820000       -7930000
# 23                26               4900        2940000       -8240000
# 24                27               5100        3060000       -8550000
# 25                28               5300        3180000       -8860000
# 26                29               5500        3300000       -9170000
# 27                30               5700        3420000       -9480000
# 28                31               5900        3540000       -9790000
# 29                32               6100        3660000      -10100000
# 30                33               6300        3780000      -10410000
# 31                34               6500        3900000      -10720000
# 32                35               6700        4020000      -11030000
# 33                36               6900        4140000      -11340000
# 34                37               7100        4260000      -11650000
# 35                38               7300        4380000      -11960000
# 36                39               7500        4500000      -12270000
# 37                40               7700        4620000      -12580000
# 38                41               7900        4740000      -12890000
# 39                42               8100        4860000      -13200000
#
#     PL-balance_CN  PL-balance_US  PL-balance_CO  PL-balance_UKR
# 0         -570000         -69999        -120000          128684
# 1         -700000         -33333        -100000          231578
# 2         -830000           3333         -80000          334473
# 3         -960000          40000         -60000          437368
# 4        -1090000          76666         -40000          540262
# 5        -1220000         113333         -20000          643157
# 6        -1350000         150000              0          746052
# 7        -1480000         186667          20000          848947
# 8        -1610000         223333          40000          951841
# 9        -1740000         260000          60000         1054736
# 10       -1870000         296667          80000         1157631
# 11       -2000000         333333         100000         1260525
# 12       -2130000         370000         120000         1363420
# 13       -2260000         406667         140000         1466315
# 14       -2390000         443333         160000         1569209
# 15       -2520000         480000         180000         1672104
# 16       -2650000         516667         200000         1774999
# 17       -2780000         553334         220000         1877894
# 18       -2910000         590000         240000         1980788
# 19       -3040000         626667         260000         2083683
# 20       -3170000         663334         280000         2186578
# 21       -3300000         700000         300000         2289472
# 22       -3430000         736667         320000         2392367
# 23       -3560000         773334         340000         2495262
# 24       -3690000         810000         360000         2598156
# 25       -3820000         846667         380000         2701051
# 26       -3950000         883334         400000         2803946
# 27       -4080000         920001         420000         2906841
# 28       -4210000         956667         440000         3009735
# 29       -4340000         993334         460000         3112630
# 30       -4470000        1030001         480000         3215525
# 31       -4600000        1066667         500000         3318419
# 32       -4730000        1103334         520000         3421314
# 33       -4860000        1140001         540000         3524209
# 34       -4990000        1176667         560000         3627103
# 35       -5120000        1213334         580000         3729998
# 36       -5250000        1250001         600000         3832893
# 37       -5380000        1286668         620000         3935788
# 38       -5510000        1323334         640000         4038682
# 39       -5640000        1360001         660000         4141577

# %%
#Indsætter antallet af licenser som hvert datacenter potentielt kan dække. Tallene er trukket fra den tidligere groupby-funktion
a2['Number of potential licenses'] = [0, 6392,8651,490,12638]
a2.astype(dtype = int, errors = 'ignore').round(0)
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 0       Denmark      2150000            5                    430000
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses
# 0                      35833                             0
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638

# %%
#Indsætter det minimale antal af ansatte, der behøves for at dække ALLE licenser
a2['Number of employees needed'] = [0,34,45,4,64]
a2.astype(dtype = int, errors = 'ignore').round(0)
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 0       Denmark      2150000            5                    430000
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses  \
# 0                      35833                             0
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638
#
#    Number of employees needed
# 0                           0
# 1                          34
# 2                          45
# 3                           4
# 4                          64

# %%
#Udregner hvad totale medarbejderomkostningerne er pr. år såfremt ALLE licenser bliver dækket
a2['Total employee cost'] = a2['Number of employees needed']*a2['Avg Annual Employee cost']
a2.astype(dtype = int, errors = 'ignore').round(0)
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 0       Denmark      2150000            5                    430000
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses  \
# 0                      35833                             0
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638
#
#    Number of employees needed  Total employee cost
# 0                           0                    0
# 1                          34              8500000
# 2                          45              3750000
# 3                           4               400000
# 4                          64              1094736

# %%
#Da Danmark ikke får tildelt et support center (på kort sigt) grundet de høje omkostninger, fjernes Danmark fra dataframe
a2_drop_Denmark = a2.drop([0], axis=0).astype(dtype = int, errors = 'ignore').round(0)
a2_drop_Denmark
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses  \
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638
#
#    Number of employees needed  Total employee cost
# 1                          34              8500000
# 2                          45              3750000
# 3                           4               400000
# 4                          64              1094736

# %%
#Udregner differensen mellem ekstra indtjening ved insourcing og de totale medarbejderomkostninger
a2_drop_Denmark['Profit/loss']=(a2_drop_Denmark['Number of potential licenses']*profit_margin)-a2_drop_Denmark['Total employee cost']
#Udregner omkostning pr. licens (unit cost) fordelt på lande
a2_drop_Denmark['Unit cost']=a2_drop_Denmark['Total employee cost']/a2_drop_Denmark['Number of potential licenses']

a2_drop_Denmark.astype(dtype = int, errors = 'ignore').round(0)
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses  \
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638
#
#    Number of employees needed  Total employee cost  Profit/loss  Unit cost
# 1                          34              8500000     -4664800       1329
# 2                          45              3750000      1440600        433
# 3                           4               400000      -106000        816
# 4                          64              1094736      6488064         86

# %%
#Udregner netto-profitten/tabet såfremt alle supportcentre etableres med support på ALLE licenser
a2_drop_Denmark['Profit/loss'].sum()
# Out:
# 3157864.0

# %%
#Der er netto-profit på ca. 3.158.000, såfremt alle supportcentre etableres

# %%
                                           
    
                                            ####UDREGNING AF ADOPTION RATES####

# %%
#Nu beregnes omkostningerne på forskellige adoption-rates over tre år: HHv. 10%, 50% og 100% af licenserne dækkes af customer first
#Antagelse: Væksten er 10 procent pr. år. (dvs. antallet af licenser stiger med 10 procent pr. år)

#10% adoption
a2_drop_Denmark['10% adoption, y1']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*0.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['10% adoption, y2']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*1.1*0.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['10% adoption, y3']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*1.1*1.1*0.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']

#50% adoption
a2_drop_Denmark['50% adoption, y1']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*0.5)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['50% adoption, y2']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*0.5*1.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['50% adoption, y3']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*1.1*1.1*0.5)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']

#100% adoption
a2_drop_Denmark['100% adoption, y1']=np.ceil((((a2_drop_Denmark['Number of potential licenses'])-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['100% adoption, y2']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*1.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']
a2_drop_Denmark['100% adoption, y3']=np.ceil((((a2_drop_Denmark['Number of potential licenses']*1.1*1.1)-300)/200)+3)*a2_drop_Denmark['Avg Annual Employee cost']

a2_drop_Denmark.astype(dtype = int, errors = 'ignore').round(0)
# Out:
#   Support Center  Total cost  Average FTE  Avg Annual Employee cost  \
# 1         China      2500000           10                    250000
# 2           USA       750000            9                     83333
# 3      Colombia      2100000           21                    100000
# 4       Ukraine       650000           38                     17105
#
#    Avg Monthly Employee cost  Number of potential licenses  \
# 1                      20833                          6392
# 2                       6944                          8651
# 3                       8333                           490
# 4                       1425                         12638
#
#    Number of employees needed  Total employee cost  Profit/loss  Unit cost  \
# 1                          34              8500000     -4664800       1329
# 2                          45              3750000      1440600        433
# 3                           4               400000      -106000        816
# 4                          64              1094736      6488064         86
#
#    10% adoption, y1  10% adoption, y2  10% adoption, y3  50% adoption, y1  \
# 1           1250000           1500000           1500000           4500000
# 2            499998            583331            583331           1999992
# 3            200000            200000            200000            300000
# 4            136840            153945            171050            581570
#
#    50% adoption, y2  50% adoption, y3  100% adoption, y1  100% adoption, y2  \
# 1           5000000           5250000            8500000            9250000
# 2           2166658           2333324            3749985            4166650
# 3            300000            300000             400000             500000
# 4            632885            684200            1111825            1231560
#
#    100% adoption, y3
# 1           10250000
# 2            4499982
# 3             500000
# 4            1334190
